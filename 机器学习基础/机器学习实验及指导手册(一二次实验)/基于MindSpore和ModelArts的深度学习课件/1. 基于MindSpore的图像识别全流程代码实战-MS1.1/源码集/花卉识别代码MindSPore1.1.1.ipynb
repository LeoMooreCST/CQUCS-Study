# %% [markdown]
# # 实验步骤：
# 1.	数据集获取
# 2.	导入实验环境
# 3.	读取数据集
# 4.	模型构建训练
# 5.	模型预测
# 6.	模型保存和转换
#
# ## 1. 数据集获取
#
# 该数据集是开源数据集，总共包括5种花的类型：分别是daisy（雏菊，633张），dandelion（蒲公英，898张），roses（玫瑰，641张），sunflowers（向日葵，699张），tulips（郁金香，799张），保存在5个文件夹当中，总共3670张，大小大概在230M左右。为了在模型部署上线之后进行测试，数据集在这里分成了flower_train和flower_test两部分。
#
#
# 在ModelArts平台输入代码自动获取数据，获取后的数据会存在当前项目的work目录下，不会同步到OBS，如果想要查看下载的文件，可以调用终端，输入cd work命令，切换到work目录下之后，输入ls命令进行查看。

# %%
#ModelArts平台输入代码会自动下载数据，下载完成之后不需要二次运行，不然会报错。
# !wget https://professional.obs.cn-north-4.myhuaweicloud.com/flower_photos_train.zip
# !unzip flower_photos_train.zip
# !wget https://professional.obs.cn-north-4.myhuaweicloud.com/flower_photos_test.zip
# !unzip flower_photos_test.zip
# Out:
# --2021-03-18 00:58:33--  https://professional.obs.cn-north-4.myhuaweicloud.com/flower_photos_train.zip
# Resolving professional.obs.cn-north-4.myhuaweicloud.com (professional.obs.cn-north-4.myhuaweicloud.com)... 100.125.81.126, 100.125.81.190, 100.125.81.253
# Connecting to professional.obs.cn-north-4.myhuaweicloud.com (professional.obs.cn-north-4.myhuaweicloud.com)|100.125.81.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226761752 (216M) [application/zip]
# Saving to: ‘flower_photos_train.zip’
#
# flower_photos_train 100%[===================>] 216.26M   158MB/s    in 1.4s
#
# 2021-03-18 00:58:35 (158 MB/s) - ‘flower_photos_train.zip’ saved [226761752/226761752]
#
# Archive:  flower_photos_train.zip
#    creating: flower_photos_train/
#    creating: flower_photos_train/daisy/
#   inflating: flower_photos_train/daisy/10140303196_b88d3d6cec.jpg
#   inflating: flower_photos_train/daisy/10172379554_b296050f82_n.jpg
#   inflating: flower_photos_train/daisy/10172567486_2748826a8b.jpg
#   inflating: flower_photos_train/daisy/10172636503_21bededa75_n.jpg
#   inflating: flower_photos_train/daisy/102841525_bd6628ae3c.jpg
#   inflating: flower_photos_train/daisy/1031799732_e7f4008c03.jpg
#   inflating: flower_photos_train/daisy/10391248763_1d16681106_n.jpg
#   inflating: flower_photos_train/daisy/10437754174_22ec990b77_m.jpg
#   inflating: flower_photos_train/daisy/10437770546_8bb6f7bdd3_m.jpg
#   inflating: flower_photos_train/daisy/10437929963_bc13eebe0c.jpg
#   inflating: flower_photos_train/daisy/10466290366_cc72e33532.jpg
#   inflating: flower_photos_train/daisy/10466558316_a7198b87e2.jpg
#   inflating: flower_photos_train/daisy/10555749515_13a12a026e.jpg
#   inflating: flower_photos_train/daisy/10555815624_dc211569b0.jpg
#   inflating: flower_photos_train/daisy/10555826524_423eb8bf71_n.jpg
#   inflating: flower_photos_train/daisy/10559679065_50d2b16f6d.jpg
#   inflating: flower_photos_train/daisy/105806915_a9c13e2106_n.jpg
#   inflating: flower_photos_train/daisy/10712722853_5632165b04.jpg
#   inflating: flower_photos_train/daisy/107592979_aaa9cdfe78_m.jpg
#   inflating: flower_photos_train/daisy/10770585085_4742b9dac3_n.jpg
#   inflating: flower_photos_train/daisy/10841136265_af473efc60.jpg
#   inflating: flower_photos_train/daisy/10993710036_2033222c91.jpg
#   inflating: flower_photos_train/daisy/10993818044_4c19b86c82.jpg
#   inflating: flower_photos_train/daisy/10994032453_ac7f8d9e2e.jpg
#   inflating: flower_photos_train/daisy/11023214096_b5b39fab08.jpg
#   inflating: flower_photos_train/daisy/11023272144_fce94401f2_m.jpg
#   inflating: flower_photos_train/daisy/11023277956_8980d53169_m.jpg
#   inflating: flower_photos_train/daisy/11124324295_503f3a0804.jpg
#   inflating: flower_photos_train/daisy/1140299375_3aa7024466.jpg
#   inflating: flower_photos_train/daisy/11439894966_dca877f0cd.jpg
#   inflating: flower_photos_train/daisy/1150395827_6f94a5c6e4_n.jpg
#   inflating: flower_photos_train/daisy/11642632_1e7627a2cc.jpg
#   inflating: flower_photos_train/daisy/11834945233_a53b7a92ac_m.jpg
#   inflating: flower_photos_train/daisy/11870378973_2ec1919f12.jpg
#   inflating: flower_photos_train/daisy/11891885265_ccefec7284_n.jpg
#   inflating: flower_photos_train/daisy/12193032636_b50ae7db35_n.jpg
#   inflating: flower_photos_train/daisy/12348343085_d4c396e5b5_m.jpg
#   inflating: flower_photos_train/daisy/12585131704_0f64b17059_m.jpg
#   inflating: flower_photos_train/daisy/12601254324_3cb62c254a_m.jpg
#   inflating: flower_photos_train/daisy/1265350143_6e2b276ec9.jpg
#   inflating: flower_photos_train/daisy/12701063955_4840594ea6_n.jpg
#   inflating: flower_photos_train/daisy/1285423653_18926dc2c8_n.jpg
#   inflating: flower_photos_train/daisy/1286274236_1d7ac84efb_n.jpg
#   inflating: flower_photos_train/daisy/12891819633_e4c82b51e8.jpg
#   inflating: flower_photos_train/daisy/1299501272_59d9da5510_n.jpg
#   inflating: flower_photos_train/daisy/1306119996_ab8ae14d72_n.jpg
#   inflating: flower_photos_train/daisy/1314069875_da8dc023c6_m.jpg
#   inflating: flower_photos_train/daisy/1342002397_9503c97b49.jpg
#   inflating: flower_photos_train/daisy/1344985627_c3115e2d71_n.jpg
#   inflating: flower_photos_train/daisy/13491959645_2cd9df44d6_n.jpg
#   inflating: flower_photos_train/daisy/1354396826_2868631432_m.jpg
#   inflating: flower_photos_train/daisy/1355787476_32e9f2a30b.jpg
#   inflating: flower_photos_train/daisy/13583238844_573df2de8e_m.jpg
#   inflating: flower_photos_train/daisy/1374193928_a52320eafa.jpg
#   inflating: flower_photos_train/daisy/13826249325_f61cb15f86_n.jpg
#   inflating: flower_photos_train/daisy/13901930939_a7733c03f0_n.jpg
#   inflating: flower_photos_train/daisy/1392131677_116ec04751.jpg
#   inflating: flower_photos_train/daisy/1392946544_115acbb2d9.jpg
#   inflating: flower_photos_train/daisy/13953307149_f8de6a768c_m.jpg
#   inflating: flower_photos_train/daisy/1396526833_fb867165be_n.jpg
#   inflating: flower_photos_train/daisy/13977181862_f8237b6b52.jpg
#   inflating: flower_photos_train/daisy/14021430525_e06baf93a9.jpg
#   inflating: flower_photos_train/daisy/14073784469_ffb12f3387_n.jpg
#   inflating: flower_photos_train/daisy/14087947408_9779257411_n.jpg
#   inflating: flower_photos_train/daisy/14088053307_1a13a0bf91_n.jpg
#   inflating: flower_photos_train/daisy/14114116486_0bb6649bc1_m.jpg
#   inflating: flower_photos_train/daisy/14147016029_8d3cf2414e.jpg
#   inflating: flower_photos_train/daisy/14163875973_467224aaf5_m.jpg
#   inflating: flower_photos_train/daisy/14167534527_781ceb1b7a_n.jpg
#   inflating: flower_photos_train/daisy/14167543177_cd36b54ac6_n.jpg
#   inflating: flower_photos_train/daisy/14219214466_3ca6104eae_m.jpg
#   inflating: flower_photos_train/daisy/14221836990_90374e6b34.jpg
#   inflating: flower_photos_train/daisy/14221848160_7f0a37c395.jpg
#   inflating: flower_photos_train/daisy/14245834619_153624f836.jpg
#   inflating: flower_photos_train/daisy/14264136211_9531fbc144.jpg
#   inflating: flower_photos_train/daisy/14272874304_47c0a46f5a.jpg
#   inflating: flower_photos_train/daisy/14307766919_fac3c37a6b_m.jpg
#   inflating: flower_photos_train/daisy/14330343061_99478302d4_m.jpg
#   inflating: flower_photos_train/daisy/14332947164_9b13513c71_m.jpg
#   inflating: flower_photos_train/daisy/14333681205_a07c9f1752_m.jpg
#   inflating: flower_photos_train/daisy/14350958832_29bdd3a254.jpg
#   inflating: flower_photos_train/daisy/14354051035_1037b30421_n.jpg
#   inflating: flower_photos_train/daisy/14372713423_61e2daae88.jpg
#   inflating: flower_photos_train/daisy/14399435971_ea5868c792.jpg
#   inflating: flower_photos_train/daisy/14402451388_56545a374a_n.jpg
#   inflating: flower_photos_train/daisy/1441939151_b271408c8d_n.jpg
#   inflating: flower_photos_train/daisy/14421389519_d5fd353eb4.jpg
#   inflating: flower_photos_train/daisy/14471433500_cdaa22e3ea_m.jpg
#   inflating: flower_photos_train/daisy/14485782498_fb342ec301.jpg
#   inflating: flower_photos_train/daisy/14507818175_05219b051c_m.jpg
#   inflating: flower_photos_train/daisy/14523675369_97c31d0b5b.jpg
#   inflating: flower_photos_train/daisy/14551098743_2842e7a004_n.jpg
#   inflating: flower_photos_train/daisy/14554906452_35f066ffe9_n.jpg
#   inflating: flower_photos_train/daisy/14564545365_1f1d267bf1_n.jpg
#   inflating: flower_photos_train/daisy/14569895116_32f0dcb0f9.jpg
#   inflating: flower_photos_train/daisy/14591326135_930703dbed_m.jpg
#   inflating: flower_photos_train/daisy/14600779226_7bbc288d40_m.jpg
#   inflating: flower_photos_train/daisy/14613443462_d4ed356201.jpg
#   inflating: flower_photos_train/daisy/14621687774_ec52811acd_n.jpg
#   inflating: flower_photos_train/daisy/14674743211_f68b13f6d9.jpg
#   inflating: flower_photos_train/daisy/14698531521_0c2f0c6539.jpg
#   inflating: flower_photos_train/daisy/147068564_32bb4350cc.jpg
#   inflating: flower_photos_train/daisy/14707111433_cce08ee007.jpg
#   inflating: flower_photos_train/daisy/14716799982_ed6d626a66.jpg
#   inflating: flower_photos_train/daisy/14816364517_2423021484_m.jpg
#   inflating: flower_photos_train/daisy/14866200659_6462c723cb_m.jpg
#   inflating: flower_photos_train/daisy/14907815010_bff495449f.jpg
#   inflating: flower_photos_train/daisy/14921511479_7b0a647795.jpg
#   inflating: flower_photos_train/daisy/15029936576_8d6f96c72c_n.jpg
#   inflating: flower_photos_train/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: flower_photos_train/daisy/15306268004_4680ba95e1.jpg
#   inflating: flower_photos_train/daisy/153210866_03cc9f2f36.jpg
#   inflating: flower_photos_train/daisy/15327813273_06cdf42210.jpg
#   inflating: flower_photos_train/daisy/154332674_453cea64f4.jpg
#   inflating: flower_photos_train/daisy/15760153042_a2a90e9da5_m.jpg
#   inflating: flower_photos_train/daisy/15760811380_4d686c892b_n.jpg
#   inflating: flower_photos_train/daisy/15784493690_b1858cdb2b_n.jpg
#   inflating: flower_photos_train/daisy/15813862117_dedcd1c56f_m.jpg
#   inflating: flower_photos_train/daisy/15853110333_229c439e7f.jpg
#   inflating: flower_photos_train/daisy/158869618_f1a6704236_n.jpg
#   inflating: flower_photos_train/daisy/16020253176_60f2a6a5ca_n.jpg
#   inflating: flower_photos_train/daisy/16025261368_911703a536_n.jpg
#   inflating: flower_photos_train/daisy/16121105382_b96251e506_m.jpg
#   inflating: flower_photos_train/daisy/16161045294_70c76ce846_n.jpg
#   inflating: flower_photos_train/daisy/162362896_99c7d851c8_n.jpg
#   inflating: flower_photos_train/daisy/162362897_1d21b70621_m.jpg
#   inflating: flower_photos_train/daisy/16291797949_a1b1b7c2bd_n.jpg
#   inflating: flower_photos_train/daisy/16360180712_b72695928c_n.jpg
#   inflating: flower_photos_train/daisy/163978992_8128b49d3e_n.jpg
#   inflating: flower_photos_train/daisy/16401288243_36112bd52f_m.jpg
#   inflating: flower_photos_train/daisy/16482676953_5296227d40_n.jpg
#   inflating: flower_photos_train/daisy/16492248512_61a57dfec1_m.jpg
#   inflating: flower_photos_train/daisy/16527403771_2391f137c4_n.jpg
#   inflating: flower_photos_train/daisy/1656856503_447e5b0f03.jpg
#   inflating: flower_photos_train/daisy/16737503507_431768a927.jpg
#   inflating: flower_photos_train/daisy/16819071290_471d99e166_m.jpg
#   inflating: flower_photos_train/daisy/16833748795_b681b2839f_n.jpg
#   inflating: flower_photos_train/daisy/169371301_d9b91a2a42.jpg
#   inflating: flower_photos_train/daisy/17027891179_3edc08f4f6.jpg
#   inflating: flower_photos_train/daisy/17101762155_2577a28395.jpg
#   inflating: flower_photos_train/daisy/171972704_389cf7a953.jpg
#   inflating: flower_photos_train/daisy/17249393016_093e915012_n.jpg
#   inflating: flower_photos_train/daisy/172882635_4cc7b86731_m.jpg
#   inflating: flower_photos_train/daisy/172967318_c596d082cc.jpg
#   inflating: flower_photos_train/daisy/173350276_02817aa8d5.jpg
#   inflating: flower_photos_train/daisy/17357636476_1953c07aa4_n.jpg
#   inflating: flower_photos_train/daisy/174131220_c853df1287.jpg
#   inflating: flower_photos_train/daisy/175106495_53ebdef092_n.jpg
#   inflating: flower_photos_train/daisy/176375506_201859bb92_m.jpg
#   inflating: flower_photos_train/daisy/18023717391_e2c9089e10.jpg
#   inflating: flower_photos_train/daisy/181007802_7cab5ee78e_n.jpg
#   inflating: flower_photos_train/daisy/18195689904_46619b7e16_n.jpg
#   inflating: flower_photos_train/daisy/18203367608_07a04e98a4_n.jpg
#   inflating: flower_photos_train/daisy/18354545086_693ea7bc2a.jpg
#   inflating: flower_photos_train/daisy/18400014056_2e4c601ed5.jpg
#   inflating: flower_photos_train/daisy/18442919723_d1251d3e14_n.jpg
#   inflating: flower_photos_train/daisy/18474740346_ffdaa18032.jpg
#   inflating: flower_photos_train/daisy/18582579815_4c6637e9ff_m.jpg
#   inflating: flower_photos_train/daisy/18622672908_eab6dc9140_n.jpg
#   inflating: flower_photos_train/daisy/18635898912_eb8e058ef0.jpg
#   inflating: flower_photos_train/daisy/18679421522_3be9879e32.jpg
#   inflating: flower_photos_train/daisy/18684594849_7dd3634f5e_n.jpg
#   inflating: flower_photos_train/daisy/18711159980_11d3bd5042.jpg
#   inflating: flower_photos_train/daisy/1879567877_8ed2a5faa7_n.jpg
#   inflating: flower_photos_train/daisy/18901817451_43e2b45f6c.jpg
#   inflating: flower_photos_train/daisy/19019544592_b64469bf84_n.jpg
#   inflating: flower_photos_train/daisy/19177263840_6a316ea639.jpg
#   inflating: flower_photos_train/daisy/19178753159_a471bf4b6b.jpg
#   inflating: flower_photos_train/daisy/19280272025_57de24e940_m.jpg
#   inflating: flower_photos_train/daisy/19544831049_0d738d4872_m.jpg
#   inflating: flower_photos_train/daisy/1955336401_fbb206d6ef_n.jpg
#   inflating: flower_photos_train/daisy/19653086178_28156b7ce4_m.jpg
#   inflating: flower_photos_train/daisy/19813618946_93818db7aa_m.jpg
#   inflating: flower_photos_train/daisy/19834392829_7d697871f6.jpg
#   inflating: flower_photos_train/daisy/19865728236_a62f8f445b_n.jpg
#   inflating: flower_photos_train/daisy/19975899671_ebc42b7865_n.jpg
#   inflating: flower_photos_train/daisy/2001380507_19488ff96a_n.jpg
#   inflating: flower_photos_train/daisy/20182559506_40a112f762.jpg
#   inflating: flower_photos_train/daisy/2019064575_7656b9340f_m.jpg
#   inflating: flower_photos_train/daisy/20289938802_e16fa9f23d.jpg
#   inflating: flower_photos_train/daisy/20329326505_a777c71cc2.jpg
#   inflating: flower_photos_train/daisy/2045022175_ad087f5f60_n.jpg
#   inflating: flower_photos_train/daisy/2057816617_18448093d0_n.jpg
#   inflating: flower_photos_train/daisy/20580471306_ab5a011b15_n.jpg
#   inflating: flower_photos_train/daisy/20619292635_9857a12d54.jpg
#   inflating: flower_photos_train/daisy/20685027271_0e7306e7c1_n.jpg
#   inflating: flower_photos_train/daisy/20703737132_179560d0fb.jpg
#   inflating: flower_photos_train/daisy/20773528301_008fcbc5a1_n.jpg
#   inflating: flower_photos_train/daisy/2077865117_9ed85191ae_n.jpg
#   inflating: flower_photos_train/daisy/2087343668_ef4fb95787_n.jpg
#   inflating: flower_photos_train/daisy/20948886919_cac7844f34_n.jpg
#   inflating: flower_photos_train/daisy/21402054779_759366efb0_n.jpg
#   inflating: flower_photos_train/daisy/21626652132_97e1318bb8_m.jpg
#   inflating: flower_photos_train/daisy/21652746_cc379e0eea_m.jpg
#   inflating: flower_photos_train/daisy/21805938544_bf6bb0e4bc.jpg
#   inflating: flower_photos_train/daisy/2213954589_c7da4b1486.jpg
#   inflating: flower_photos_train/daisy/22244161124_53e457bb66_n.jpg
#   inflating: flower_photos_train/daisy/22873310415_3a5674ec10_m.jpg
#   inflating: flower_photos_train/daisy/23095658544_7226386954_n.jpg
#   inflating: flower_photos_train/daisy/2331133004_582772d58f_m.jpg
#   inflating: flower_photos_train/daisy/2346726545_2ebce2b2a6.jpg
#   inflating: flower_photos_train/daisy/2349640101_212c275aa7.jpg
#   inflating: flower_photos_train/daisy/2351206867_084e57bd97.jpg
#   inflating: flower_photos_train/daisy/2365428551_39f83f10bf_n.jpg
#   inflating: flower_photos_train/daisy/2408024540_37f0be7cc0_n.jpg
#   inflating: flower_photos_train/daisy/2454280135_ac3aa75cdc_n.jpg
#   inflating: flower_photos_train/daisy/2454280137_e1637536ae_n.jpg
#   inflating: flower_photos_train/daisy/2473825306_62fd5f8785_n.jpg
#   inflating: flower_photos_train/daisy/2476937534_21b285aa46_n.jpg
#   inflating: flower_photos_train/daisy/2479956481_8d1a9699be_n.jpg
#   inflating: flower_photos_train/daisy/2480569557_f4e1f0dcb8_n.jpg
#   inflating: flower_photos_train/daisy/2481823240_eab0d86921.jpg
#   inflating: flower_photos_train/daisy/2482982436_a2145359e0_n.jpg
#   inflating: flower_photos_train/daisy/2488902131_3417698611_n.jpg
#   inflating: flower_photos_train/daisy/2498632196_e47a472d5a.jpg
#   inflating: flower_photos_train/daisy/2509545845_99e79cb8a2_n.jpg
#   inflating: flower_photos_train/daisy/2511306240_9047015f2d_n.jpg
#   inflating: flower_photos_train/daisy/2513618768_ff7c004796_m.jpg
#   inflating: flower_photos_train/daisy/2514748602_343d4727c0_n.jpg
#   inflating: flower_photos_train/daisy/2520369272_1dcdb5a892_m.jpg
#   inflating: flower_photos_train/daisy/2521408074_e6f86daf21_n.jpg
#   inflating: flower_photos_train/daisy/253426762_9793d43fcd.jpg
#   inflating: flower_photos_train/daisy/2536529152_33ef3ee078_n.jpg
#   inflating: flower_photos_train/daisy/2538504987_fe524b92a8_n.jpg
#   inflating: flower_photos_train/daisy/2539552964_921cf645ba_n.jpg
#   inflating: flower_photos_train/daisy/2551708158_1f10e81e11.jpg
#   inflating: flower_photos_train/daisy/2556503265_63ae6b9e0e_m.jpg
#   inflating: flower_photos_train/daisy/2561352120_7961d8263f.jpg
#   inflating: flower_photos_train/daisy/2561371688_c80a4fe957_n.jpg
#   inflating: flower_photos_train/daisy/2567033807_8e918c53d8_n.jpg
#   inflating: flower_photos_train/daisy/2573240560_ff7ffdd449.jpg
#   inflating: flower_photos_train/daisy/2578695910_5ab8ee17c1_n.jpg
#   inflating: flower_photos_train/daisy/2579018590_74359dcf1a_m.jpg
#   inflating: flower_photos_train/daisy/2581171297_b0a249b92b_n.jpg
#   inflating: flower_photos_train/daisy/2590291468_2635d3e4e0_n.jpg
#   inflating: flower_photos_train/daisy/2599662355_7782218c83.jpg
#   inflating: flower_photos_train/daisy/2607132536_d95198e619_n.jpg
#   inflating: flower_photos_train/daisy/2611119198_9d46b94392.jpg
#   inflating: flower_photos_train/daisy/2612704455_efce1c2144_m.jpg
#   inflating: flower_photos_train/daisy/2617111535_54c2ac8462.jpg
#   inflating: flower_photos_train/daisy/2619413565_61a6cd3ac9_m.jpg
#   inflating: flower_photos_train/daisy/2621723097_736febb4a4_n.jpg
#   inflating: flower_photos_train/daisy/2627815904_919373e7f5.jpg
#   inflating: flower_photos_train/daisy/2632216904_274aa17433.jpg
#   inflating: flower_photos_train/daisy/2635314490_e12d3b0f36_m.jpg
#   inflating: flower_photos_train/daisy/2641151167_3bf1349606_m.jpg
#   inflating: flower_photos_train/daisy/2641979584_2b21c3fe29_m.jpg
#   inflating: flower_photos_train/daisy/2642408410_61545fdc83_n.jpg
#   inflating: flower_photos_train/daisy/2646438199_b309cffd65_n.jpg
#   inflating: flower_photos_train/daisy/2649404904_b7a91991bb_n.jpg
#   inflating: flower_photos_train/daisy/2666572212_2caca8de9f_n.jpg
#   inflating: flower_photos_train/daisy/267148092_4bb874af58.jpg
#   inflating: flower_photos_train/daisy/2713919471_301fcc941f.jpg
#   inflating: flower_photos_train/daisy/2812442552_3eed5fb9f2_m.jpg
#   inflating: flower_photos_train/daisy/2828733818_1c1ed0089d_n.jpg
#   inflating: flower_photos_train/daisy/2838487505_6c3b48efa5_m.jpg
#   inflating: flower_photos_train/daisy/2862944799_45bc8e7302.jpg
#   inflating: flower_photos_train/daisy/286875003_f7c0e1882d.jpg
#   inflating: flower_photos_train/daisy/2877860110_a842f8b14a_m.jpg
#   inflating: flower_photos_train/daisy/2889325612_f2fc403ff0_m.jpg
#   inflating: flower_photos_train/daisy/2901376034_cdb4bac26b_m.jpg
#   inflating: flower_photos_train/daisy/2908212142_5437fa67ff_n.jpg
#   inflating: flower_photos_train/daisy/294451721_5106537b34.jpg
#   inflating: flower_photos_train/daisy/299129811_d6ebda9970.jpg
#   inflating: flower_photos_train/daisy/301964511_fab84ea1c1.jpg
#   inflating: flower_photos_train/daisy/3025866885_22fb0b61c6_n.jpg
#   inflating: flower_photos_train/daisy/302782756_d35cb3e468.jpg
#   inflating: flower_photos_train/daisy/305160642_53cde0f44f.jpg
#   inflating: flower_photos_train/daisy/3080880039_4f1bd592e5_n.jpg
#   inflating: flower_photos_train/daisy/3084924076_4d5c5711af_m.jpg
#   inflating: flower_photos_train/daisy/3098641292_76c908ba1f_n.jpg
#   inflating: flower_photos_train/daisy/3117644024_1cbb59a509_n.jpg
#   inflating: flower_photos_train/daisy/3275951182_d27921af97_n.jpg
#   inflating: flower_photos_train/daisy/3285641623_da0e47f49a.jpg
#   inflating: flower_photos_train/daisy/3310644753_5607eb96a4_m.jpg
#   inflating: flower_photos_train/daisy/3326037909_b5ae370722_n.jpg
#   inflating: flower_photos_train/daisy/3336704121_cfeb67a7d7.jpg
#   inflating: flower_photos_train/daisy/3337536080_1db19964fe.jpg
#   inflating: flower_photos_train/daisy/3337643329_accc9b5426.jpg
#   inflating: flower_photos_train/daisy/3338077096_3a8ed0e2bc_m.jpg
#   inflating: flower_photos_train/daisy/3356112863_75da8bca2c_m.jpg
#   inflating: flower_photos_train/daisy/3379332157_04724f6480.jpg
#   inflating: flower_photos_train/daisy/3386988684_bc5a66005e.jpg
#   inflating: flower_photos_train/daisy/3410906335_37e8a24b1c_n.jpg
#   inflating: flower_photos_train/daisy/3415180846_d7b5cced14_m.jpg
#   inflating: flower_photos_train/daisy/3440366251_5b9bdf27c9_m.jpg
#   inflating: flower_photos_train/daisy/3445110406_0c1616d2e3_n.jpg
#   inflating: flower_photos_train/daisy/3450822975_7e77d67636_n.jpg
#   inflating: flower_photos_train/daisy/3456403987_5bd5fa6ece_n.jpg
#   inflating: flower_photos_train/daisy/3463313493_9497aa47e5_n.jpg
#   inflating: flower_photos_train/daisy/3468498624_d082f99e98.jpg
#   inflating: flower_photos_train/daisy/3474942718_c418dae6f1.jpg
#   inflating: flower_photos_train/daisy/3475870145_685a19116d.jpg
#   inflating: flower_photos_train/daisy/3483303007_42e3f90da7.jpg
#   inflating: flower_photos_train/daisy/3491933306_43cfe2cfbe.jpg
#   inflating: flower_photos_train/daisy/3494265422_9dba8f2191_n.jpg
#   inflating: flower_photos_train/daisy/3504430338_77d6a7fab4_n.jpg
#   inflating: flower_photos_train/daisy/3506866918_61dd5fc53b_n.jpg
#   inflating: flower_photos_train/daisy/3533954656_79156c8473.jpg
#   inflating: flower_photos_train/daisy/3546455114_cd2dea5e02.jpg
#   inflating: flower_photos_train/daisy/3552074420_2a0a7166db_m.jpg
#   inflating: flower_photos_train/daisy/3588872598_e0f9a1d2a1_m.jpg
#   inflating: flower_photos_train/daisy/3598615130_578ed30e5f.jpg
#   inflating: flower_photos_train/daisy/3611577717_f3a7a8c416_n.jpg
#   inflating: flower_photos_train/daisy/3625257860_33efeef614_m.jpg
#   inflating: flower_photos_train/daisy/3627678863_557552c879_m.jpg
#   inflating: flower_photos_train/daisy/3628485766_4ff937954a_n.jpg
#   inflating: flower_photos_train/daisy/3633489595_a037a9b7a4_m.jpg
#   inflating: flower_photos_train/daisy/3637428148_a1dcccafa9_n.jpg
#   inflating: flower_photos_train/daisy/3639009391_0f910681b7.jpg
#   inflating: flower_photos_train/daisy/3640845041_80a92c4205_n.jpg
#   inflating: flower_photos_train/daisy/3661613900_b15ca1d35d_m.jpg
#   inflating: flower_photos_train/daisy/367020749_3c9a652d75.jpg
#   inflating: flower_photos_train/daisy/3695826945_9f374e8a00_m.jpg
#   inflating: flower_photos_train/daisy/3699235066_fc09a02dfe_m.jpg
#   inflating: flower_photos_train/daisy/3703643767_dee82cdef9_n.jpg
#   inflating: flower_photos_train/daisy/3704305945_a80e60e2f6_m.jpg
#   inflating: flower_photos_train/daisy/3704306975_75b74497d8.jpg
#   inflating: flower_photos_train/daisy/3706420943_66f3214862_n.jpg
#   inflating: flower_photos_train/daisy/3711723108_65247a3170.jpg
#   inflating: flower_photos_train/daisy/3711892138_b8c953fdc1_z.jpg
#   inflating: flower_photos_train/daisy/3713290261_8a66de23ab.jpg
#   inflating: flower_photos_train/daisy/3717746329_53f515c6a6_m.jpg
#   inflating: flower_photos_train/daisy/3720632920_93cf1cc7f3_m.jpg
#   inflating: flower_photos_train/daisy/3750250718_eb61146c5f.jpg
#   inflating: flower_photos_train/daisy/3750771898_cfd50090ba_n.jpg
#   inflating: flower_photos_train/daisy/3758221664_b19116d61f.jpg
#   inflating: flower_photos_train/daisy/3764116502_f394428ee0_n.jpg
#   inflating: flower_photos_train/daisy/3773181799_5def396456.jpg
#   inflating: flower_photos_train/daisy/3780380240_ef9ec1b737_m.jpg
#   inflating: flower_photos_train/daisy/3848258315_ed2fde4fb4.jpg
#   inflating: flower_photos_train/daisy/3861452393_14d2f95157_m.jpg
#   inflating: flower_photos_train/daisy/3900172983_9312fdf39c_n.jpg
#   inflating: flower_photos_train/daisy/391364010_4b0942d400_m.jpg
#   inflating: flower_photos_train/daisy/391364011_5beaaa1ae2_m.jpg
#   inflating: flower_photos_train/daisy/3939135368_0af5c4982a_n.jpg
#   inflating: flower_photos_train/daisy/3957488431_52a447c0e8_m.jpg
#   inflating: flower_photos_train/daisy/3962240986_0661edc43a_n.jpg
#   inflating: flower_photos_train/daisy/3963330924_6c6a3fa7be_n.jpg
#   inflating: flower_photos_train/daisy/3975010332_3209f9f447_m.jpg
#   inflating: flower_photos_train/daisy/3999978867_c67c79597f_m.jpg
#   inflating: flower_photos_train/daisy/4065883015_4bb6010cb7_n.jpg
#   inflating: flower_photos_train/daisy/4085794721_7cd88e0a6c_m.jpg
#   inflating: flower_photos_train/daisy/4117918318_3c8935289b_m.jpg
#   inflating: flower_photos_train/daisy/4131565290_0585c4dd5a_n.jpg
#   inflating: flower_photos_train/daisy/413815348_764ae83088.jpg
#   inflating: flower_photos_train/daisy/4141147800_813f660b47.jpg
#   inflating: flower_photos_train/daisy/4144275653_7c02d47d9b.jpg
#   inflating: flower_photos_train/daisy/422094774_28acc69a8b_n.jpg
#   inflating: flower_photos_train/daisy/4222584034_8964cbd3de.jpg
#   inflating: flower_photos_train/daisy/4229503616_9b8a42123c_n.jpg
#   inflating: flower_photos_train/daisy/4258408909_b7cc92741c_m.jpg
#   inflating: flower_photos_train/daisy/4268817944_cdbdb226ae.jpg
#   inflating: flower_photos_train/daisy/4276898893_609d11db8b.jpg
#   inflating: flower_photos_train/daisy/4278442064_a5a598524b_m.jpg
#   inflating: flower_photos_train/daisy/4281102584_c548a69b81_m.jpg
#   inflating: flower_photos_train/daisy/4286053334_a75541f20b_m.jpg
#   inflating: flower_photos_train/daisy/4301689054_20519e5b68.jpg
#   inflating: flower_photos_train/daisy/4318007511_e9f4311936_n.jpg
#   inflating: flower_photos_train/daisy/433037739_6a030e5912.jpg
#   inflating: flower_photos_train/daisy/4333085242_bbeb3e2841_m.jpg
#   inflating: flower_photos_train/daisy/433837534_1dbf798b73.jpg
#   inflating: flower_photos_train/daisy/435283392_72e4c5b5d6_m.jpg
#   inflating: flower_photos_train/daisy/437859108_173fb33c98.jpg
#   inflating: flower_photos_train/daisy/4407065098_ef25f1ccac_n.jpg
#   inflating: flower_photos_train/daisy/4413849849_b8d2f3bcf1_n.jpg
#   inflating: flower_photos_train/daisy/4432271543_01c56ca3a9.jpg
#   inflating: flower_photos_train/daisy/4434592930_6610d51fca_m.jpg
#   inflating: flower_photos_train/daisy/4440480869_632ce6aff3_n.jpg
#   inflating: flower_photos_train/daisy/446484749_4044affcaf_n.jpg
#   inflating: flower_photos_train/daisy/4482623536_b9fb5ae41f_n.jpg
#   inflating: flower_photos_train/daisy/4496202781_1d8e776ff5_n.jpg
#   inflating: flower_photos_train/daisy/450128527_fd35742d44.jpg
#   inflating: flower_photos_train/daisy/4511693548_20f9bd2b9c_m.jpg
#   inflating: flower_photos_train/daisy/452854574_59492f119a_m.jpg
#   inflating: flower_photos_train/daisy/4534460263_8e9611db3c_n.jpg
#   inflating: flower_photos_train/daisy/4538877108_3c793f7987_m.jpg
#   inflating: flower_photos_train/daisy/4540555191_3254dc4608_n.jpg
#   inflating: flower_photos_train/daisy/4544110929_a7de65d65f_n.jpg
#   inflating: flower_photos_train/daisy/4561871220_47f420ca59_m.jpg
#   inflating: flower_photos_train/daisy/4563059851_45a9d21a75.jpg
#   inflating: flower_photos_train/daisy/4565255237_9ba29c4d4e_n.jpg
#   inflating: flower_photos_train/daisy/4581199679_867652c3f1_n.jpg
#   inflating: flower_photos_train/daisy/4598422221_b37313a3e3_n.jpg
#   inflating: flower_photos_train/daisy/459931395_24bf6531fe_n.jpg
#   inflating: flower_photos_train/daisy/4610018126_21f438d2dc_m.jpg
#   inflating: flower_photos_train/daisy/4613992315_143ccc2a10_m.jpg
#   inflating: flower_photos_train/daisy/4646886118_b5c5ceaf6d_n.jpg
#   inflating: flower_photos_train/daisy/4654579740_6671a53627_m.jpg
#   inflating: flower_photos_train/daisy/4657354814_f368762c53_m.jpg
#   inflating: flower_photos_train/daisy/4666648087_b10f376f19.jpg
#   inflating: flower_photos_train/daisy/4668543441_79040ca329_n.jpg
#   inflating: flower_photos_train/daisy/4669117051_ce61e91b76.jpg
#   inflating: flower_photos_train/daisy/4683997791_56e7d3c03c_n.jpg
#   inflating: flower_photos_train/daisy/4694730335_2553e77aa5_z.jpg
#   inflating: flower_photos_train/daisy/4694734757_5c563d38dd_n.jpg
#   inflating: flower_photos_train/daisy/4697206799_19dd2a3193_m.jpg
#   inflating: flower_photos_train/daisy/4724713781_d169f98a35.jpg
#   inflating: flower_photos_train/daisy/4727955343_0bb23ac4ae.jpg
#   inflating: flower_photos_train/daisy/4746633946_23933c0810.jpg
#   inflating: flower_photos_train/daisy/4753134939_8e87649db6.jpg
#   inflating: flower_photos_train/daisy/4757448834_a29a9538c9_n.jpg
#   inflating: flower_photos_train/daisy/476856232_7c35952f40_n.jpg
#   inflating: flower_photos_train/daisy/476857510_d2b30175de_n.jpg
#   inflating: flower_photos_train/daisy/4792826628_aa5e5a9804_n.jpg
#   inflating: flower_photos_train/daisy/4814515275_6e25a6c18f.jpg
#   inflating: flower_photos_train/daisy/4820415253_15bc3b6833_n.jpg
#   inflating: flower_photos_train/daisy/4837182901_69a6cc782b_n.jpg
#   inflating: flower_photos_train/daisy/483886997_27ee798327.jpg
#   inflating: flower_photos_train/daisy/4851353993_2cbbbd1040_n.jpg
#   inflating: flower_photos_train/daisy/4858518329_7563eb0baa_m.jpg
#   inflating: flower_photos_train/daisy/4861391074_c3e122dab0_m.jpg
#   inflating: flower_photos_train/daisy/4865691548_00319261b8.jpg
#   inflating: flower_photos_train/daisy/488202750_c420cbce61.jpg
#   inflating: flower_photos_train/daisy/4890424315_6a59696357_n.jpg
#   inflating: flower_photos_train/daisy/4897587985_f9293ea1ed.jpg
#   inflating: flower_photos_train/daisy/4923279674_e7f8e70794_n.jpg
#   inflating: flower_photos_train/daisy/495098110_3a4bb30042_n.jpg
#   inflating: flower_photos_train/daisy/498159452_b71afd65ba.jpg
#   inflating: flower_photos_train/daisy/4993492878_11fd4f5d12.jpg
#   inflating: flower_photos_train/daisy/5014137563_d03eb0ed75_n.jpg
#   inflating: flower_photos_train/daisy/5054771689_00dd40b971_n.jpg
#   inflating: flower_photos_train/daisy/5058708968_8bdcd29e63_n.jpg
#   inflating: flower_photos_train/daisy/506018088_4f7a15a7c5_n.jpg
#   inflating: flower_photos_train/daisy/506348009_9ecff8b6ef.jpg
#   inflating: flower_photos_train/daisy/506493250_e9ca42fe3d.jpg
#   inflating: flower_photos_train/daisy/5087720485_c0914fb623.jpg
#   inflating: flower_photos_train/daisy/510844526_858b8fe4db.jpg
#   inflating: flower_photos_train/daisy/5109508979_68e3530791_m.jpg
#   inflating: flower_photos_train/daisy/5110105726_53eb7a93be_m.jpg
#   inflating: flower_photos_train/daisy/5110107234_12ddc0206b_m.jpg
#   inflating: flower_photos_train/daisy/5110109540_beed4ed162_m.jpg
#   inflating: flower_photos_train/daisy/5110110938_9da91455c4_m.jpg
#   inflating: flower_photos_train/daisy/512177035_70afc925c8.jpg
#   inflating: flower_photos_train/daisy/512477177_d9004cbcf1_n.jpg
#   inflating: flower_photos_train/daisy/5133243796_44de429de5_m.jpg
#   inflating: flower_photos_train/daisy/5135131051_102d4878ca_n.jpg
#   inflating: flower_photos_train/daisy/515112668_a49c69455a.jpg
#   inflating: flower_photos_train/daisy/517054463_036db655a1_m.jpg
#   inflating: flower_photos_train/daisy/517054467_d82d323c33_m.jpg
#   inflating: flower_photos_train/daisy/519880292_7a3a6c6b69.jpg
#   inflating: flower_photos_train/daisy/520752848_4b87fb91a4.jpg
#   inflating: flower_photos_train/daisy/521762040_f26f2e08dd.jpg
#   inflating: flower_photos_train/daisy/525271784_013ddccd1b_m.jpg
#   inflating: flower_photos_train/daisy/525780443_bba812c26a_m.jpg
#   inflating: flower_photos_train/daisy/530738000_4df7e4786b.jpg
#   inflating: flower_photos_train/daisy/534547364_3f6b7279d2_n.jpg
#   inflating: flower_photos_train/daisy/538920244_59899a78f8_n.jpg
#   inflating: flower_photos_train/daisy/5434742166_35773eba57_m.jpg
#   inflating: flower_photos_train/daisy/5434901893_4550be3f84_m.jpg
#   inflating: flower_photos_train/daisy/5434913005_409c1e8b56_n.jpg
#   inflating: flower_photos_train/daisy/5434914569_e9b982fde0_n.jpg
#   inflating: flower_photos_train/daisy/5435513198_90ce39f1aa_n.jpg
#   inflating: flower_photos_train/daisy/5435521200_92029bbe2b_n.jpg
#   inflating: flower_photos_train/daisy/5435522104_1d6a61b431_n.jpg
#   inflating: flower_photos_train/daisy/5459481183_18d2d49e44_m.jpg
#   inflating: flower_photos_train/daisy/5512287917_9f5d3f0f98_n.jpg
#   inflating: flower_photos_train/daisy/5547758_eea9edfd54_n.jpg
#   inflating: flower_photos_train/daisy/5561775629_a2b709b3a4_n.jpg
#   inflating: flower_photos_train/daisy/5574421625_61b1f49b3f_m.jpg
#   inflating: flower_photos_train/daisy/5577555349_2e8490259b.jpg
#   inflating: flower_photos_train/daisy/5586977262_6b24412805_n.jpg
#   inflating: flower_photos_train/daisy/5602738326_97121e007d_n.jpg
#   inflating: flower_photos_train/daisy/5608389827_a42a46f760.jpg
#   inflating: flower_photos_train/daisy/5623010186_796ca8d29a.jpg
#   inflating: flower_photos_train/daisy/5626784099_b36dd3fb11_n.jpg
#   inflating: flower_photos_train/daisy/5626895440_97a0ec04c2_n.jpg
#   inflating: flower_photos_train/daisy/5632774792_0fa33d17eb_n.jpg
#   inflating: flower_photos_train/daisy/5665834973_76bd6c6523_m.jpg
#   inflating: flower_photos_train/daisy/5665838969_fe217988b9_m.jpg
#   inflating: flower_photos_train/daisy/5673551_01d1ea993e_n.jpg
#   inflating: flower_photos_train/daisy/5673728_71b8cb57eb.jpg
#   inflating: flower_photos_train/daisy/5679288570_b4c52e76d5.jpg
#   inflating: flower_photos_train/daisy/5684911529_88a7ae32ba_n.jpg
#   inflating: flower_photos_train/daisy/5693459303_e61d9a9533.jpg
#   inflating: flower_photos_train/daisy/5700781400_65761f3fce.jpg
#   inflating: flower_photos_train/daisy/5714327423_50af0cffe9.jpg
#   inflating: flower_photos_train/daisy/5722473541_ffac1ae67e_n.jpg
#   inflating: flower_photos_train/daisy/5739768868_9f982684f9_n.jpg
#   inflating: flower_photos_train/daisy/5765646947_82e95a9cc9_n.jpg
#   inflating: flower_photos_train/daisy/5769217520_c90efc3c93_m.jpg
#   inflating: flower_photos_train/daisy/5773652803_574b51414f_n.jpg
#   inflating: flower_photos_train/daisy/5794835_d15905c7c8_n.jpg
#   inflating: flower_photos_train/daisy/5794839_200acd910c_n.jpg
#   inflating: flower_photos_train/daisy/5795159787_ebb51a5e75.jpg
#   inflating: flower_photos_train/daisy/5796562389_ae43c83317_m.jpg
#   inflating: flower_photos_train/daisy/5809489674_5659b3ae5d_n.jpg
#   inflating: flower_photos_train/daisy/5811226952_4650ed70ae_n.jpg
#   inflating: flower_photos_train/daisy/5853276960_d08f90fff6.jpg
#   inflating: flower_photos_train/daisy/5869147563_66fb88119d.jpg
#   inflating: flower_photos_train/daisy/5874818796_3efbb8769d.jpg
#   inflating: flower_photos_train/daisy/5876455546_32049e5585.jpg
#   inflating: flower_photos_train/daisy/5881907044_92a85a05c8_n.jpg
#   inflating: flower_photos_train/daisy/5883162120_dc7274af76_n.jpg
#   inflating: flower_photos_train/daisy/5884807222_22f5326ba8_m.jpg
#   inflating: flower_photos_train/daisy/5885826924_38fdc6bcaa_n.jpg
#   inflating: flower_photos_train/daisy/5944315415_2be8abeb2f_m.jpg
#   inflating: flower_photos_train/daisy/5948835387_5a98d39eff_m.jpg
#   inflating: flower_photos_train/daisy/5973488341_50bdf6cee3_n.jpg
#   inflating: flower_photos_train/daisy/5973491805_556bba93cc.jpg
#   inflating: flower_photos_train/daisy/5981645737_29eceac291_m.jpg
#   inflating: flower_photos_train/daisy/5997702776_c7bc37aa6b_n.jpg
#   inflating: flower_photos_train/daisy/6054952060_c88612f3c5_n.jpg
#   inflating: flower_photos_train/daisy/6089825811_80f253fbe1.jpg
#   inflating: flower_photos_train/daisy/6095817094_3a5b1d793d.jpg
#   inflating: flower_photos_train/daisy/6136947177_47ff445eb4_n.jpg
#   inflating: flower_photos_train/daisy/6148728633_27afc47b0c_m.jpg
#   inflating: flower_photos_train/daisy/6207492986_0ff91f3296.jpg
#   inflating: flower_photos_train/daisy/6208851904_9d916ebb32_n.jpg
#   inflating: flower_photos_train/daisy/6210664514_f1d211217a.jpg
#   inflating: flower_photos_train/daisy/6299498346_b9774b6500.jpg
#   inflating: flower_photos_train/daisy/6299910262_336309ffa5_n.jpg
#   inflating: flower_photos_train/daisy/6323721068_3d3394af6d_n.jpg
#   inflating: flower_photos_train/daisy/6480809573_76a0074b69_n.jpg
#   inflating: flower_photos_train/daisy/6480809771_b1e14c5cc2_m.jpg
#   inflating: flower_photos_train/daisy/6529588249_d9cbe68aab_n.jpg
#   inflating: flower_photos_train/daisy/6596277835_9f86da54bb.jpg
#   inflating: flower_photos_train/daisy/676120388_28f03069c3.jpg
#   inflating: flower_photos_train/daisy/6776075110_1ea7a09dd4_n.jpg
#   inflating: flower_photos_train/daisy/6864242336_0d12713fe5_n.jpg
#   inflating: flower_photos_train/daisy/6884975451_c74f445d69_m.jpg
#   inflating: flower_photos_train/daisy/6910811638_aa6f17df23.jpg
#   inflating: flower_photos_train/daisy/6950173662_5e9473003e_n.jpg
#   inflating: flower_photos_train/daisy/695778683_890c46ebac.jpg
#   inflating: flower_photos_train/daisy/6978826370_7b9aa7c7d5.jpg
#   inflating: flower_photos_train/daisy/705422469_ffa28c566d.jpg
#   inflating: flower_photos_train/daisy/7066602021_2647457985_m.jpg
#   inflating: flower_photos_train/daisy/7133935763_82b17c8e1b_n.jpg
#   inflating: flower_photos_train/daisy/7189043225_2fe781439a_n.jpg
#   inflating: flower_photos_train/daisy/7191221492_610035de7c_m.jpg
#   inflating: flower_photos_train/daisy/7199968650_72afc16d31_m.jpg
#   inflating: flower_photos_train/daisy/721595842_bacd80a6ac.jpg
#   inflating: flower_photos_train/daisy/7227973870_806d9d3e42_n.jpg
#   inflating: flower_photos_train/daisy/7288989324_c25d9febbf.jpg
#   inflating: flower_photos_train/daisy/7320089276_87b544e341.jpg
#   inflating: flower_photos_train/daisy/7335886184_d06a83f640.jpg
#   inflating: flower_photos_train/daisy/7358085448_b317d11cd5.jpg
#   inflating: flower_photos_train/daisy/7377004908_5bc0cde347_n.jpg
#   inflating: flower_photos_train/daisy/7410356270_9dff4d0e2e_n.jpg
#   inflating: flower_photos_train/daisy/7416083788_fcb4c4f27e_n.jpg
#   inflating: flower_photos_train/daisy/7454630692_ab2d67dd18_m.jpg
#   inflating: flower_photos_train/daisy/7538403124_f2fc48750a.jpg
#   inflating: flower_photos_train/daisy/754248840_95092de274.jpg
#   inflating: flower_photos_train/daisy/754296579_30a9ae018c_n.jpg
#   inflating: flower_photos_train/daisy/7568630428_8cf0fc16ff_n.jpg
#   inflating: flower_photos_train/daisy/7629784968_b953501902_n.jpg
#   inflating: flower_photos_train/daisy/7630511450_02d3292e90.jpg
#   inflating: flower_photos_train/daisy/7630517248_98fb8bee1f_n.jpg
#   inflating: flower_photos_train/daisy/7630520686_e3a61ac763.jpg
#   inflating: flower_photos_train/daisy/7633425046_8293e3d0e9_m.jpg
#   inflating: flower_photos_train/daisy/7669550908_bc5a11276f_n.jpg
#   inflating: flower_photos_train/daisy/7702332000_3f21ef4571_n.jpg
#   inflating: flower_photos_train/daisy/7749368884_1fc58c67ff_n.jpg
#   inflating: flower_photos_train/daisy/7790614422_4557928ab9_n.jpg
#   inflating: flower_photos_train/daisy/7924174040_444d5bbb8a.jpg
#   inflating: flower_photos_train/daisy/799952628_bf836677fa_n.jpg
#   inflating: flower_photos_train/daisy/799964360_7e07a227ea_n.jpg
#   inflating: flower_photos_train/daisy/8008258043_5457dd254b_n.jpg
#   inflating: flower_photos_train/daisy/8021540573_c56cf9070d_n.jpg
#   inflating: flower_photos_train/daisy/8063844363_db3f4dea85.jpg
#   inflating: flower_photos_train/daisy/8071646795_2fdc89ab7a_n.jpg
#   inflating: flower_photos_train/daisy/8085329197_41d53a21e2_n.jpg
#   inflating: flower_photos_train/daisy/8094774544_35465c1c64.jpg
#   inflating: flower_photos_train/daisy/8120563761_ed5620664f_m.jpg
#   inflating: flower_photos_train/daisy/8127252886_96558c23d1.jpg
#   inflating: flower_photos_train/daisy/813445367_187ecf080a_n.jpg
#   inflating: flower_photos_train/daisy/8348621545_8f02b82662_n.jpg
#   inflating: flower_photos_train/daisy/835750256_3f91a147ef_n.jpg
#   inflating: flower_photos_train/daisy/8382667241_0f046cecdb_n.jpg
#   inflating: flower_photos_train/daisy/8383753520_8391dd80ee_m.jpg
#   inflating: flower_photos_train/daisy/8446495985_f72d851482.jpg
#   inflating: flower_photos_train/daisy/8489463746_a9839bf7e4.jpg
#   inflating: flower_photos_train/daisy/8616684075_71923bb771_n.jpg
#   inflating: flower_photos_train/daisy/8619103877_d8c82c5f34_n.jpg
#   inflating: flower_photos_train/daisy/8645839873_0151fb92bf_n.jpg
#   inflating: flower_photos_train/daisy/8671824531_64b816949e_m.jpg
#   inflating: flower_photos_train/daisy/8681746439_d6beeefbf9.jpg
#   inflating: flower_photos_train/daisy/8694909523_3ca25d449d_n.jpg
#   inflating: flower_photos_train/daisy/8696022686_1f8d62c5cb_m.jpg
#   inflating: flower_photos_train/daisy/8706810197_17b6c1f1e7.jpg
#   inflating: flower_photos_train/daisy/8708143485_38d084ac8c_n.jpg
#   inflating: flower_photos_train/daisy/8709110478_60d12efcd4_n.jpg
#   inflating: flower_photos_train/daisy/8709535323_a6bea3e43f.jpg
#   inflating: flower_photos_train/daisy/8710109684_e2c5ef6aeb_n.jpg
#   inflating: flower_photos_train/daisy/8718637649_87a0d85190_n.jpg
#   inflating: flower_photos_train/daisy/8719756744_34a5a83976_n.jpg
#   inflating: flower_photos_train/daisy/8740807508_0587f5b7b7.jpg
#   inflating: flower_photos_train/daisy/8742143296_fed9fa007c.jpg
#   inflating: flower_photos_train/daisy/8759177308_951790e00d_m.jpg
#   inflating: flower_photos_train/daisy/8882282142_9be2524d38_m.jpg
#   inflating: flower_photos_train/daisy/8887005939_b19e8305ee.jpg
#   inflating: flower_photos_train/daisy/8932490012_cc08e690ba_n.jpg
#   inflating: flower_photos_train/daisy/8938566373_d129e7af75.jpg
#   inflating: flower_photos_train/daisy/8964198962_6d8593b533.jpg
#   inflating: flower_photos_train/daisy/8983779970_9d3a6a3bf2_n.jpg
#   inflating: flower_photos_train/daisy/9054268881_19792c5203_n.jpg
#   inflating: flower_photos_train/daisy/9094631844_1a6abca29e.jpg
#   inflating: flower_photos_train/daisy/909609509_a05ccb8127.jpg
#   inflating: flower_photos_train/daisy/9120905231_329598304e.jpg
#   inflating: flower_photos_train/daisy/9146733107_98b15d3892_m.jpg
#   inflating: flower_photos_train/daisy/9158041313_7a6a102f7a_n.jpg
#   inflating: flower_photos_train/daisy/9161647994_e39b65cb9c_n.jpg
#   inflating: flower_photos_train/daisy/9175280426_40ecc395b8_m.jpg
#   inflating: flower_photos_train/daisy/9180706736_092d43088c.jpg
#   inflating: flower_photos_train/daisy/9204730092_a7f2182347.jpg
#   inflating: flower_photos_train/daisy/9242705328_eee8402a8d.jpg
#   inflating: flower_photos_train/daisy/9244082319_b1f7e2d8b0_n.jpg
#   inflating: flower_photos_train/daisy/9286947622_4822f4fc21.jpg
#   inflating: flower_photos_train/daisy/9299302012_958c70564c_n.jpg
#   inflating: flower_photos_train/daisy/9310226774_d1b8f5d9c9.jpg
#   inflating: flower_photos_train/daisy/9321854387_5f77c926cb_n.jpg
#   inflating: flower_photos_train/daisy/9345273630_af3550031d.jpg
#   inflating: flower_photos_train/daisy/9346508462_f0af3163f4.jpg
#   inflating: flower_photos_train/daisy/9350942387_5b1d043c26_n.jpg
#   inflating: flower_photos_train/daisy/9467543719_c4800becbb_m.jpg
#   inflating: flower_photos_train/daisy/9489270024_1b05f08492_m.jpg
#   inflating: flower_photos_train/daisy/9496209717_25a6ebdab6_m.jpg
#   inflating: flower_photos_train/daisy/9515186037_3be48fe68f.jpg
#   inflating: flower_photos_train/daisy/9529916092_de70623523_n.jpg
#   inflating: flower_photos_train/daisy/9593034725_0062f0d24e_n.jpg
#   inflating: flower_photos_train/daisy/9595857626_979c45e5bf_n.jpg
#   inflating: flower_photos_train/daisy/9611923744_013b29e4da_n.jpg
#   inflating: flower_photos_train/daisy/9922116524_ab4a2533fe_n.jpg
#    creating: flower_photos_train/dandelion/
#   inflating: flower_photos_train/dandelion/10043234166_e6dd915111_n.jpg
#   inflating: flower_photos_train/dandelion/10200780773_c6051a7d71_n.jpg
#   inflating: flower_photos_train/dandelion/10294487385_92a0676c7d_m.jpg
#   inflating: flower_photos_train/dandelion/10437652486_aa86c14985.jpg
#   inflating: flower_photos_train/dandelion/10477378514_9ffbcec4cf_m.jpg
#   inflating: flower_photos_train/dandelion/10486992895_20b344ce2d_n.jpg
#   inflating: flower_photos_train/dandelion/10617162044_8740d4dd9f_n.jpg
#   inflating: flower_photos_train/dandelion/10617191174_9a01753241_n.jpg
#   inflating: flower_photos_train/dandelion/1074999133_1e4a1e042e.jpg
#   inflating: flower_photos_train/dandelion/10777398353_5a20bb218c.jpg
#   inflating: flower_photos_train/dandelion/10778387133_9141024b10.jpg
#   inflating: flower_photos_train/dandelion/10779476016_9130714dc0.jpg
#   inflating: flower_photos_train/dandelion/1080179756_5f05350a59.jpg
#   inflating: flower_photos_train/dandelion/10828951106_c3cd47983f.jpg
#   inflating: flower_photos_train/dandelion/10946896405_81d2d50941_m.jpg
#   inflating: flower_photos_train/dandelion/11124381625_24b17662bd_n.jpg
#   inflating: flower_photos_train/dandelion/1128626197_3f52424215_n.jpg
#   inflating: flower_photos_train/dandelion/11296320473_1d9261ddcb.jpg
#   inflating: flower_photos_train/dandelion/11465213433_847c4fa261.jpg
#   inflating: flower_photos_train/dandelion/11595255065_d9550012fc.jpg
#   inflating: flower_photos_train/dandelion/11768468623_9399b5111b_n.jpg
#   inflating: flower_photos_train/dandelion/11775820493_10fedf4bff_n.jpg
#   inflating: flower_photos_train/dandelion/1193386857_3ae53574f2_m.jpg
#   inflating: flower_photos_train/dandelion/1195255751_d58b3d3076.jpg
#   inflating: flower_photos_train/dandelion/12094442595_297494dba4_m.jpg
#   inflating: flower_photos_train/dandelion/1241011700_261ae180ca.jpg
#   inflating: flower_photos_train/dandelion/126012913_edf771c564_n.jpg
#   inflating: flower_photos_train/dandelion/1273326361_b90ea56d0d_m.jpg
#   inflating: flower_photos_train/dandelion/129019877_8eea2978ca_m.jpg
#   inflating: flower_photos_train/dandelion/1297972485_33266a18d9.jpg
#   inflating: flower_photos_train/dandelion/12998979765_3de89e7195_n.jpg
#   inflating: flower_photos_train/dandelion/130733200_fbe28eea19.jpg
#   inflating: flower_photos_train/dandelion/13331969914_890082d898_n.jpg
#   inflating: flower_photos_train/dandelion/13386618495_3df1f1330d.jpg
#   inflating: flower_photos_train/dandelion/13471273823_4800ca8eec.jpg
#   inflating: flower_photos_train/dandelion/1353279846_7e6b87606d.jpg
#   inflating: flower_photos_train/dandelion/13560152823_9da5e48c87_m.jpg
#   inflating: flower_photos_train/dandelion/136011860_44ca0b2835_n.jpg
#   inflating: flower_photos_train/dandelion/13651218133_b6eb8e7ed2_m.jpg
#   inflating: flower_photos_train/dandelion/13652698934_d258a6ee8c.jpg
#   inflating: flower_photos_train/dandelion/13675534854_03caf51644_m.jpg
#   inflating: flower_photos_train/dandelion/136999986_e410a68efb_n.jpg
#   inflating: flower_photos_train/dandelion/13734221225_0e04edc6b6.jpg
#   inflating: flower_photos_train/dandelion/13807932364_673b7f1c1c_n.jpg
#   inflating: flower_photos_train/dandelion/138132145_782763b84f_m.jpg
#   inflating: flower_photos_train/dandelion/138166590_47c6cb9dd0.jpg
#   inflating: flower_photos_train/dandelion/1386449001_5d6da6bde6.jpg
#   inflating: flower_photos_train/dandelion/13881700933_69a750d418_n.jpg
#   inflating: flower_photos_train/dandelion/13887031789_97437f246b.jpg
#   inflating: flower_photos_train/dandelion/13887066460_64156a9021.jpg
#   inflating: flower_photos_train/dandelion/13897156242_dca5d93075_m.jpg
#   inflating: flower_photos_train/dandelion/13900486390_5a25785645_n.jpg
#   inflating: flower_photos_train/dandelion/13910677675_4900fa3dbf_n.jpg
#   inflating: flower_photos_train/dandelion/139124974_9e3ba69f6c.jpg
#   inflating: flower_photos_train/dandelion/13916196427_50a611008f.jpg
#   inflating: flower_photos_train/dandelion/13920113_f03e867ea7_m.jpg
#   inflating: flower_photos_train/dandelion/13942846777_5571a6b0a1_n.jpg
#   inflating: flower_photos_train/dandelion/13946048982_4e6ec56987.jpg
#   inflating: flower_photos_train/dandelion/13967344688_aa629dcdee_n.jpg
#   inflating: flower_photos_train/dandelion/13968424321_1d89b33a9f_n.jpg
#   inflating: flower_photos_train/dandelion/14002252932_64d5cbdac7.jpg
#   inflating: flower_photos_train/dandelion/14003401241_543535b385.jpg
# ...
#   inflating: flower_photos_train/tulips/6958243974_8851425ddb_n.jpg
#   inflating: flower_photos_train/tulips/6958342976_a4a9483488_n.jpg
#   inflating: flower_photos_train/tulips/6958343928_7e596da4ed_m.jpg
#   inflating: flower_photos_train/tulips/6970683464_f70838ca3a_n.jpg
#   inflating: flower_photos_train/tulips/6982913043_3b873c6a25.jpg
#   inflating: flower_photos_train/tulips/6989946990_62c639ff16_n.jpg
#   inflating: flower_photos_train/tulips/6994351792_343e18cbf6_n.jpg
#   inflating: flower_photos_train/tulips/6998661030_46cbb7892a.jpg
#   inflating: flower_photos_train/tulips/7002703410_3e97b29da5_n.jpg
#   inflating: flower_photos_train/tulips/7003964080_4566470798_n.jpg
#   inflating: flower_photos_train/tulips/7042692841_f323799c0d.jpg
#   inflating: flower_photos_train/tulips/7046815693_f159e96acd_n.jpg
#   inflating: flower_photos_train/tulips/7047408023_6e98fd1e3f.jpg
#   inflating: flower_photos_train/tulips/7055500907_dcf2bb50e0.jpg
#   inflating: flower_photos_train/tulips/7064778965_ddcc6ee9f2.jpg
#   inflating: flower_photos_train/tulips/7064813645_f7f48fb527.jpg
#   inflating: flower_photos_train/tulips/7068715863_a534ac7884_n.jpg
#   inflating: flower_photos_train/tulips/7069622551_348d41c327_n.jpg
#   inflating: flower_photos_train/tulips/7070694881_e9a331fa4e_n.jpg
#   inflating: flower_photos_train/tulips/7082476907_99beef0dde.jpg
#   inflating: flower_photos_train/tulips/7082608511_f4cf233f59_n.jpg
#   inflating: flower_photos_train/tulips/7094271655_79a6f972c1_n.jpg
#   inflating: flower_photos_train/tulips/7094415739_6b29e5215c_m.jpg
#   inflating: flower_photos_train/tulips/7136973281_b2a935ce20.jpg
#   inflating: flower_photos_train/tulips/7144016605_e159b6c06b_m.jpg
#   inflating: flower_photos_train/tulips/7145978709_2d1596f462.jpg
#   inflating: flower_photos_train/tulips/7166539842_43b7e02883.jpg
#   inflating: flower_photos_train/tulips/7166550328_de0d73cfa9.jpg
#   inflating: flower_photos_train/tulips/7166552648_28b6dce578.jpg
#   inflating: flower_photos_train/tulips/7166554924_432aaae4b2_n.jpg
#   inflating: flower_photos_train/tulips/7166564830_8b34a3fd35_n.jpg
#   inflating: flower_photos_train/tulips/7166567320_0a2beb6d42.jpg
#   inflating: flower_photos_train/tulips/7166570828_7c26ca5766_n.jpg
#   inflating: flower_photos_train/tulips/7166598930_18d8686ace_n.jpg
#   inflating: flower_photos_train/tulips/7166606598_5d2cd307c3.jpg
#   inflating: flower_photos_train/tulips/7166618384_850905fc63_n.jpg
#   inflating: flower_photos_train/tulips/7166626128_8e0983ac8e_n.jpg
#   inflating: flower_photos_train/tulips/7166635566_ee240b5408_n.jpg
#   inflating: flower_photos_train/tulips/7166640338_46b15d9ec8_n.jpg
#   inflating: flower_photos_train/tulips/7166644048_b00a14f01b.jpg
#   inflating: flower_photos_train/tulips/7166646966_41d83cd703.jpg
#   inflating: flower_photos_train/tulips/7177682195_c29265748d_n.jpg
#   inflating: flower_photos_train/tulips/7179796338_05e8b1c87b.jpg
#   inflating: flower_photos_train/tulips/7205145492_baec4dbb94.jpg
#   inflating: flower_photos_train/tulips/7205698252_b972087cc2.jpg
#   inflating: flower_photos_train/tulips/7247182064_f8d6759446_n.jpg
#   inflating: flower_photos_train/tulips/7266196114_c2a736a15a_m.jpg
#   inflating: flower_photos_train/tulips/7342871880_c17fe0eb4f_m.jpg
#   inflating: flower_photos_train/tulips/738207467_fc59cfcd9b_z.jpg
#   inflating: flower_photos_train/tulips/7447655334_e8f805ab95_m.jpg
#   inflating: flower_photos_train/tulips/7448453762_aea8739f1b.jpg
#   inflating: flower_photos_train/tulips/7481204112_e3c57dd40a_n.jpg
#   inflating: flower_photos_train/tulips/7481215720_73e40f178f_n.jpg
#   inflating: flower_photos_train/tulips/7481217920_6f65766a1c_n.jpg
#   inflating: flower_photos_train/tulips/7775145448_c42e638a6a_n.jpg
#   inflating: flower_photos_train/tulips/779359602_30abcbf5bb_n.jpg
#   inflating: flower_photos_train/tulips/7806320016_fcddfc1f8f_n.jpg
#   inflating: flower_photos_train/tulips/8394186551_28eed83a94_m.jpg
#   inflating: flower_photos_train/tulips/8454707381_453b4862eb_m.jpg
#   inflating: flower_photos_train/tulips/8454719295_4276c0e9c5_n.jpg
#   inflating: flower_photos_train/tulips/8484905084_6a18c62b13_m.jpg
#   inflating: flower_photos_train/tulips/8511683706_4173683d45_m.jpg
#   inflating: flower_photos_train/tulips/8520482921_21dd204ebd_n.jpg
#   inflating: flower_photos_train/tulips/8520488975_a50d377f91.jpg
#   inflating: flower_photos_train/tulips/8521597402_4b6169ba05.jpg
#   inflating: flower_photos_train/tulips/8523133474_d2c0845b54.jpg
#   inflating: flower_photos_train/tulips/8554190977_37ac747799_m.jpg
#   inflating: flower_photos_train/tulips/8555123165_2fe57eff4f.jpg
#   inflating: flower_photos_train/tulips/8562853756_73778dac25_n.jpg
#   inflating: flower_photos_train/tulips/8572847041_d0cc07861f_n.jpg
#   inflating: flower_photos_train/tulips/8601596054_33e40c2a7a.jpg
#   inflating: flower_photos_train/tulips/8603340662_0779bd87fd.jpg
#   inflating: flower_photos_train/tulips/8605564823_7a59d3d92a.jpg
#   inflating: flower_photos_train/tulips/8614237582_74417799f4_m.jpg
#   inflating: flower_photos_train/tulips/8619064872_dea79a9eb9.jpg
#   inflating: flower_photos_train/tulips/8622237974_b362574785_n.jpg
#   inflating: flower_photos_train/tulips/8623170936_83f4152431.jpg
#   inflating: flower_photos_train/tulips/8623173256_3f0eb4c506.jpg
#   inflating: flower_photos_train/tulips/8628453641_6f87755815_m.jpg
#   inflating: flower_photos_train/tulips/8659691170_09db83d023.jpg
#   inflating: flower_photos_train/tulips/8668973377_c69527db42_m.jpg
#   inflating: flower_photos_train/tulips/8668974855_8389ecbdca_m.jpg
#   inflating: flower_photos_train/tulips/8669794378_97dda6036f_n.jpg
#   inflating: flower_photos_train/tulips/8673412732_f8fd690ee4_n.jpg
#   inflating: flower_photos_train/tulips/8673416166_620fc18e2f_n.jpg
#   inflating: flower_photos_train/tulips/8673416556_639f5c88f1_n.jpg
#   inflating: flower_photos_train/tulips/8677713853_1312f65e71.jpg
#   inflating: flower_photos_train/tulips/8681825637_837a63513a_n.jpg
#   inflating: flower_photos_train/tulips/8686013485_3c4dfbfd1f_n.jpg
#   inflating: flower_photos_train/tulips/8686332852_c6dcb2e86b.jpg
#   inflating: flower_photos_train/tulips/8687675254_c93f50d8b0_m.jpg
#   inflating: flower_photos_train/tulips/8688502760_1c8d6de921_m.jpg
#   inflating: flower_photos_train/tulips/8689672277_b289909f97_n.jpg
#   inflating: flower_photos_train/tulips/8690789564_394eb04982_n.jpg
#   inflating: flower_photos_train/tulips/8690791226_b1f015259f_n.jpg
#   inflating: flower_photos_train/tulips/8695367666_0809529eaf_n.jpg
#   inflating: flower_photos_train/tulips/8695372372_302135aeb2.jpg
#   inflating: flower_photos_train/tulips/8697784345_e75913d220.jpg
#   inflating: flower_photos_train/tulips/8702982836_75222725d7.jpg
#   inflating: flower_photos_train/tulips/8706523526_a0f161b72b.jpg
#   inflating: flower_photos_train/tulips/8708209606_d3aede4801.jpg
#   inflating: flower_photos_train/tulips/8708856019_f3be2353a4_n.jpg
#   inflating: flower_photos_train/tulips/8710148289_6fc196a0f8_n.jpg
#   inflating: flower_photos_train/tulips/8711277462_b43df5454b_m.jpg
#   inflating: flower_photos_train/tulips/8712230357_1298b8513b.jpg
#   inflating: flower_photos_train/tulips/8712243901_54d686319e_m.jpg
#   inflating: flower_photos_train/tulips/8712244311_da8e90bf8e_n.jpg
#   inflating: flower_photos_train/tulips/8712260079_c0ff42e0e2_n.jpg
#   inflating: flower_photos_train/tulips/8712263493_3db76c5f82.jpg
#   inflating: flower_photos_train/tulips/8712266605_3787e346cd_n.jpg
#   inflating: flower_photos_train/tulips/8712267391_c756f18ee7_n.jpg
#   inflating: flower_photos_train/tulips/8712267813_f7a9be2ec5.jpg
#   inflating: flower_photos_train/tulips/8712268519_f4c2c39a06_n.jpg
#   inflating: flower_photos_train/tulips/8712269349_2b933da2b8_n.jpg
#   inflating: flower_photos_train/tulips/8712270243_8512cf4fbd.jpg
#   inflating: flower_photos_train/tulips/8712270665_57b5bda0a2_n.jpg
#   inflating: flower_photos_train/tulips/8712282563_3819afb7bc.jpg
#   inflating: flower_photos_train/tulips/8713357842_9964a93473_n.jpg
#   inflating: flower_photos_train/tulips/8713387500_6a9138b41b_n.jpg
#   inflating: flower_photos_train/tulips/8713388322_e5ae26263b_n.jpg
#   inflating: flower_photos_train/tulips/8713389178_66bceb71a8_n.jpg
#   inflating: flower_photos_train/tulips/8713390684_041148dd3e_n.jpg
#   inflating: flower_photos_train/tulips/8713391394_4b679ea1e3_n.jpg
#   inflating: flower_photos_train/tulips/8713392604_90631fb809_n.jpg
#   inflating: flower_photos_train/tulips/8713394070_b24561b0a9.jpg
#   inflating: flower_photos_train/tulips/8713396140_5af8136136.jpg
#   inflating: flower_photos_train/tulips/8713397358_0505cc0176_n.jpg
#   inflating: flower_photos_train/tulips/8713397694_bcbcbba2c2_n.jpg
#   inflating: flower_photos_train/tulips/8713398114_bc96f1b624_n.jpg
#   inflating: flower_photos_train/tulips/8713398614_88202e452e_n.jpg
#   inflating: flower_photos_train/tulips/8713398906_28e59a225a_n.jpg
#   inflating: flower_photos_train/tulips/8713407768_f880df361f.jpg
#   inflating: flower_photos_train/tulips/8717900362_2aa508e9e5.jpg
#   inflating: flower_photos_train/tulips/8722514702_7ecc68691c.jpg
#   inflating: flower_photos_train/tulips/8723767533_9145dec4bd_n.jpg
#   inflating: flower_photos_train/tulips/8729501081_b993185542_m.jpg
#   inflating: flower_photos_train/tulips/8733586143_3139db6e9e_n.jpg
#   inflating: flower_photos_train/tulips/8748266132_5298a91dcf_n.jpg
#   inflating: flower_photos_train/tulips/8750288831_5e49a9f29b.jpg
#   inflating: flower_photos_train/tulips/8757486380_90952c5377.jpg
#   inflating: flower_photos_train/tulips/8762189906_8223cef62f.jpg
#   inflating: flower_photos_train/tulips/8762193202_0fbf2f6a81.jpg
#   inflating: flower_photos_train/tulips/8768645961_8f1e097170_n.jpg
#   inflating: flower_photos_train/tulips/8817622133_a42bb90e38_n.jpg
#   inflating: flower_photos_train/tulips/8838347159_746d14e6c1_m.jpg
#   inflating: flower_photos_train/tulips/8838354855_c474fc66a3_m.jpg
#   inflating: flower_photos_train/tulips/8838914676_8ef4db7f50_n.jpg
#   inflating: flower_photos_train/tulips/8838975946_f54194894e_m.jpg
#   inflating: flower_photos_train/tulips/8838983024_5c1a767878_n.jpg
#   inflating: flower_photos_train/tulips/8892851067_79242a7362_n.jpg
#   inflating: flower_photos_train/tulips/8904780994_8867d64155_n.jpg
#   inflating: flower_photos_train/tulips/8908062479_449200a1b4.jpg
#   inflating: flower_photos_train/tulips/8908097235_c3e746d36e_n.jpg
#   inflating: flower_photos_train/tulips/9019694597_2d3bbedb17.jpg
#   inflating: flower_photos_train/tulips/9030467406_05e93ff171_n.jpg
#   inflating: flower_photos_train/tulips/9048307967_40a164a459_m.jpg
#   inflating: flower_photos_train/tulips/924782410_94ed7913ca_m.jpg
#   inflating: flower_photos_train/tulips/9378657435_89fabf13c9_n.jpg
#   inflating: flower_photos_train/tulips/9444202147_405290415b_n.jpg
#   inflating: flower_photos_train/tulips/9446982168_06c4d71da3_n.jpg
#   inflating: flower_photos_train/tulips/9831362123_5aac525a99_n.jpg
#   inflating: flower_photos_train/tulips/9870557734_88eb3b9e3b_n.jpg
#   inflating: flower_photos_train/tulips/9947374414_fdf1d0861c_n.jpg
#   inflating: flower_photos_train/tulips/9947385346_3a8cacea02_n.jpg
#   inflating: flower_photos_train/tulips/9976515506_d496c5e72c.jpg
# --2021-03-18 00:58:39--  https://professional.obs.cn-north-4.myhuaweicloud.com/flower_photos_test.zip
# Resolving professional.obs.cn-north-4.myhuaweicloud.com (professional.obs.cn-north-4.myhuaweicloud.com)... 100.125.81.126, 100.125.81.253, 100.125.81.190
# Connecting to professional.obs.cn-north-4.myhuaweicloud.com (professional.obs.cn-north-4.myhuaweicloud.com)|100.125.81.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3006583 (2.9M) [application/zip]
# Saving to: ‘flower_photos_test.zip’
#
# flower_photos_test. 100%[===================>]   2.87M  --.-KB/s    in 0.01s
#
# 2021-03-18 00:58:39 (268 MB/s) - ‘flower_photos_test.zip’ saved [3006583/3006583]
#
# Archive:  flower_photos_test.zip
#    creating: flower_photos_test/
#    creating: flower_photos_test/daisy/
#   inflating: flower_photos_test/daisy/100080576_f52e8ee070_n.jpg
#   inflating: flower_photos_test/daisy/134372449_0f7166d96c_n.jpg
#   inflating: flower_photos_test/daisy/134409839_71069a95d1_m.jpg
#   inflating: flower_photos_test/daisy/144076848_57e1d662e3_m.jpg
#   inflating: flower_photos_test/daisy/144099102_bf63a41e4f_n.jpg
#   inflating: flower_photos_test/daisy/144603918_b9de002f60_m.jpg
#   inflating: flower_photos_test/daisy/25360380_1a881a5648.jpg
#   inflating: flower_photos_test/daisy/43474673_7bb4465a86.jpg
#   inflating: flower_photos_test/daisy/54377391_15648e8d18.jpg
#   inflating: flower_photos_test/daisy/99306615_739eb94b9e_m.jpg
#    creating: flower_photos_test/dandelion/
#   inflating: flower_photos_test/dandelion/10443973_aeb97513fc_m.jpg
#   inflating: flower_photos_test/dandelion/10683189_bd6e371b97.jpg
#   inflating: flower_photos_test/dandelion/10919961_0af657c4e8.jpg
#   inflating: flower_photos_test/dandelion/11405573_24a8a838cc_n.jpg
#   inflating: flower_photos_test/dandelion/11545123_50a340b473_m.jpg
#   inflating: flower_photos_test/dandelion/13290033_ebd7c7abba_n.jpg
#   inflating: flower_photos_test/dandelion/14829055_2a2e646a8f_m.jpg
#   inflating: flower_photos_test/dandelion/15987457_49dc11bf4b.jpg
#   inflating: flower_photos_test/dandelion/16041975_2f6c1596e5.jpg
#   inflating: flower_photos_test/dandelion/16159487_3a6615a565_n.jpg
#   inflating: flower_photos_test/dandelion/16987075_9a690a2183.jpg
#   inflating: flower_photos_test/dandelion/61242541_a04395e6bc.jpg
#   inflating: flower_photos_test/LICENSE.txt
#    creating: flower_photos_test/roses/
#   inflating: flower_photos_test/roses/145862135_ab710de93c_n.jpg
#   inflating: flower_photos_test/roses/159079265_d77a9ac920_n.jpg
#   inflating: flower_photos_test/roses/160954292_6c2b4fda65_n.jpg
#   inflating: flower_photos_test/roses/165985535_7178ce6350.jpg
#   inflating: flower_photos_test/roses/172311368_49412f881b.jpg
#   inflating: flower_photos_test/roses/229488796_21ac6ee16d_n.jpg
#   inflating: flower_photos_test/roses/269037241_07fceff56a_m.jpg
#   inflating: flower_photos_test/roses/272481307_1eb47ba3e0_n.jpg
#   inflating: flower_photos_test/roses/295257304_de893fc94d.jpg
#   inflating: flower_photos_test/roses/298670754_f25edda891.jpg
#    creating: flower_photos_test/sunflowers/
#   inflating: flower_photos_test/sunflowers/164670176_9f5b9c7965.jpg
#   inflating: flower_photos_test/sunflowers/164670455_29d8e02bbd_n.jpg
#   inflating: flower_photos_test/sunflowers/164671753_ab36d9cbb7_n.jpg
#   inflating: flower_photos_test/sunflowers/164672339_f2b5b164f6.jpg
#   inflating: flower_photos_test/sunflowers/175638423_058c07afb9.jpg
#   inflating: flower_photos_test/sunflowers/184682652_c927a49226_m.jpg
#   inflating: flower_photos_test/sunflowers/184682920_97ae41ce60_m.jpg
#   inflating: flower_photos_test/sunflowers/184683023_737fec5b18.jpg
#   inflating: flower_photos_test/sunflowers/193874852_fb633d8d00_n.jpg
#   inflating: flower_photos_test/sunflowers/193878348_43571127b9_n.jpg
#    creating: flower_photos_test/tulips/
#   inflating: flower_photos_test/tulips/122450705_9885fff3c4_n.jpg
#   inflating: flower_photos_test/tulips/130684927_a05164ba13_m.jpg
#   inflating: flower_photos_test/tulips/130684941_d1abfa3be6_m.jpg
#   inflating: flower_photos_test/tulips/130685040_3c2fcec63e_n.jpg
#   inflating: flower_photos_test/tulips/130685245_dcdd23836f_m.jpg
#   inflating: flower_photos_test/tulips/133692329_c1150ed811_n.jpg
#   inflating: flower_photos_test/tulips/133858239_3eaa8a91fd_n.jpg
#   inflating: flower_photos_test/tulips/133960364_d87f883c15_n.jpg
#   inflating: flower_photos_test/tulips/134143359_71fa8dd9a4.jpg
#   inflating: flower_photos_test/tulips/135994133_4f306fe4bf_n.jpg

# %%
# 隐藏警告
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. 导入实验环境
#
# ### 步骤 1	导入相应的模块
#
# os模块主要用于处理文件和目录，比如：获取当前目录下文件，删除制定文件，改变目录，查看文件大小等；MindSpore是目前业界最流行的深度学习框架，在图像，语音，文本，目标检测等领域都有深入的应用，也是该实验的核心，主要用于定义占位符，定义变量，创建卷积神经网络模型；numpy是一个基于python的科学计算包，在该实验中主要用来处理数值运算。

# %%
#easydict模块用于以属性的方式访问字典的值
from easydict import EasyDict as edict
#os模块主要用于处理文件和目录
import os

import numpy as np
import matplotlib.pyplot as plt

import mindspore
#导入mindspore框架数据集
import mindspore.dataset as ds
#vision.c_transforms模块是处理图像增强的高性能模块，用于数据增强图像数据改进训练模型。
from mindspore.dataset.vision import c_transforms as vision
from mindspore import context
import mindspore.nn as nn
from mindspore.train import Model
from mindspore.nn.optim.momentum import Momentum
from mindspore.train.callback import ModelCheckpoint, CheckpointConfig, LossMonitor
from mindspore import Tensor
from mindspore.train.serialization import export
from mindspore.train.loss_scale_manager import FixedLossScaleManager
from mindspore.train.serialization import load_checkpoint, load_param_into_net
import mindspore.ops as ops

# 设置MindSpore的执行模式和设备
context.set_context(mode=context.GRAPH_MODE, device_target="Ascend")

# %% [markdown]
# ### 步骤 2	定义变量

# %%
cfg = edict({
    'data_path': 'flower_photos_train',   #训练数据集，如果是zip文件需要解压
    'test_path':'flower_photos_test',     #测试数据集，如果是zip文件需要解压
    'data_size': 3616,
    'HEIGHT': 224,  # 图片高度
    'WIDTH': 224,  # 图片宽度
    '_R_MEAN': 123.68,
    '_G_MEAN': 116.78,
    '_B_MEAN': 103.94,
    '_R_STD': 1,
    '_G_STD': 1,
    '_B_STD':1,
    '_RESIZE_SIDE_MIN': 256,
    '_RESIZE_SIDE_MAX': 512,
    
    'batch_size': 32,
    'num_class': 5,     # 分类类别
    'epoch_size': 150,  # 训练次数
    'loss_scale_num':1024,
    
    'prefix': 'resnet-ai',
    'directory': './model_resnet',
    'save_checkpoint_steps': 10,
})

# %% [markdown]
# ## 3. 读取数据集
# 数据读取并处理流程如下：
#
# MindSpore的mindspore.dataset提供了ImageFolderDataset函数，可以直接读取文件夹图片数据并映射文件夹名字为其标签(label)。这里我们使用ImageFolderDataset函数读取'daisy','dandelion','roses','sunflowers','tulips'数据。并将这五类标签映射为：{'daisy':0,'dandelion':1,'roses':2,'sunflowers':3,'tulips':4}，使用RandomCropDecodeResize、HWC2CHW、shuffle进行数据预处理。

# %%
# 数据处理
def read_data(path,config,usage="train"):
    #从目录中读取图像的源数据集。
    dataset = ds.ImageFolderDataset(path,
                                   class_indexing={'daisy':0,'dandelion':1,'roses':2,'sunflowers':3,'tulips':4})
    # define map operations
    decode_op = vision.Decode()
    normalize_op = vision.Normalize(mean=[cfg._R_MEAN, cfg._G_MEAN, cfg._B_MEAN], std=[cfg._R_STD, cfg._G_STD, cfg._B_STD])
    resize_op = vision.Resize(cfg._RESIZE_SIDE_MIN)
    center_crop_op = vision.CenterCrop((cfg.HEIGHT, cfg.WIDTH))
    horizontal_flip_op = vision.RandomHorizontalFlip()
    channelswap_op = vision.HWC2CHW()
    random_crop_decode_resize_op = vision.RandomCropDecodeResize((cfg.HEIGHT, cfg.WIDTH), (0.5, 1.0), (1.0, 1.0), max_attempts=100)

    if usage == 'train':
        dataset = dataset.map(input_columns="image", operations=random_crop_decode_resize_op)
        dataset = dataset.map(input_columns="image", operations=horizontal_flip_op)
    else:
        dataset = dataset.map(input_columns="image", operations=decode_op)
        dataset = dataset.map(input_columns="image", operations=resize_op)
        dataset = dataset.map(input_columns="image", operations=center_crop_op)

    dataset = dataset.map(input_columns="image", operations=normalize_op)
    dataset = dataset.map(input_columns="image", operations=channelswap_op)

    if usage == 'train':
        dataset = dataset.shuffle(buffer_size=10000)  # 10000 as in imageNet train script
        dataset = dataset.batch(cfg.batch_size, drop_remainder=True)
    else:
        dataset = dataset.batch(1, drop_remainder=True)
    dataset = dataset.repeat(1)
    dataset.map_model = 4

    return dataset
   
de_train = read_data(cfg.data_path,cfg,usage="train")
de_test = read_data(cfg.test_path,cfg,usage="test")
print('训练数据集数量：',de_train.get_dataset_size()*cfg.batch_size)#get_dataset_size()获取批处理的大小。
print('测试数据集数量：',de_test.get_dataset_size())


de_dataset = de_train
data_next = de_dataset.create_dict_iterator(output_numpy=True).__next__()
print('通道数/图像长/宽：', data_next['image'][0,...].shape)
print('一张图像的标签样式：', data_next['label'][0])  # 一共5类，用0-4的数字表达类别。

plt.figure()
plt.imshow(data_next['image'][0,0,...])
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# 训练数据集数量： 3616
# 测试数据集数量： 52
# 通道数/图像长/宽： (3, 224, 224)
# 一张图像的标签样式： 2

# %% [markdown]
# ## 4. 模型构建训练
# 搭建ResNet50神经网络模型
# ### 步骤 1	定义模型

# %%
"""ResNet."""
def _weight_variable(shape, factor=0.01):
    init_value = np.random.randn(*shape).astype(np.float32) * factor
    return Tensor(init_value)


def _conv3x3(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 3, 3)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=3, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _conv1x1(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 1, 1)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=1, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _conv7x7(in_channel, out_channel, stride=1):
    weight_shape = (out_channel, in_channel, 7, 7)
    weight = _weight_variable(weight_shape)
    return nn.Conv2d(in_channel, out_channel,
                     kernel_size=7, stride=stride, padding=0, pad_mode='same', weight_init=weight)


def _bn(channel):
    return nn.BatchNorm2d(channel, eps=1e-4, momentum=0.9,
                          gamma_init=1, beta_init=0, moving_mean_init=0, moving_var_init=1)


def _bn_last(channel):
    return nn.BatchNorm2d(channel, eps=1e-4, momentum=0.9,
                          gamma_init=0, beta_init=0, moving_mean_init=0, moving_var_init=1)


def _fc(in_channel, out_channel):
    weight_shape = (out_channel, in_channel)
    weight = _weight_variable(weight_shape)
    return nn.Dense(in_channel, out_channel, has_bias=True, weight_init=weight, bias_init=0)


class ResidualBlock(nn.Cell):
    """
    ResNet V1 residual block definition.

    Args:
        in_channel (int): Input channel.
        out_channel (int): Output channel.
        stride (int): Stride size for the first convolutional layer. Default: 1.

    Returns:
        Tensor, output tensor.

    Examples:
        >>> ResidualBlock(3, 256, stride=2)
    """
    expansion = 4

    def __init__(self,
                 in_channel,
                 out_channel,
                 stride=1):
        super(ResidualBlock, self).__init__()

        channel = out_channel // self.expansion
        self.conv1 = _conv1x1(in_channel, channel, stride=1)
        self.bn1 = _bn(channel)

        self.conv2 = _conv3x3(channel, channel, stride=stride)
        self.bn2 = _bn(channel)

        self.conv3 = _conv1x1(channel, out_channel, stride=1)
        self.bn3 = _bn_last(out_channel)

        self.relu = nn.ReLU()

        self.down_sample = False

        if stride != 1 or in_channel != out_channel:
            self.down_sample = True
        self.down_sample_layer = None

        if self.down_sample:
            self.down_sample_layer = nn.SequentialCell([_conv1x1(in_channel, out_channel, stride),
                                                        _bn(out_channel)])
        self.add = ops.Add()

    def construct(self, x): # pylint: disable=missing-docstring
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        if self.down_sample:
            identity = self.down_sample_layer(identity)

        out = self.add(out, identity)
        out = self.relu(out)

        return out


class ResNet(nn.Cell):
    """
    ResNet architecture.

    Args:
        block (Cell): Block for network.
        layer_nums (list): Numbers of block in different layers.
        in_channels (list): Input channel in each layer.
        out_channels (list): Output channel in each layer.
        strides (list):  Stride size in each layer.
        num_classes (int): The number of classes that the training images are belonging to.
    Returns:
        Tensor, output tensor.

    Examples:
        >>> ResNet(ResidualBlock,
        >>>        [3, 4, 6, 3],
        >>>        [64, 256, 512, 1024],
        >>>        [256, 512, 1024, 2048],
        >>>        [1, 2, 2, 2],
        >>>        10)
    """

    def __init__(self,
                 block,
                 layer_nums,
                 in_channels,
                 out_channels,
                 strides,
                 num_classes):
        super(ResNet, self).__init__()

        if not len(layer_nums) == len(in_channels) == len(out_channels) == 4:
            raise ValueError("the length of layer_num, in_channels, out_channels list must be 4!")

        self.conv1 = _conv7x7(3, 64, stride=2)
        self.bn1 = _bn(64)
        self.relu = ops.ReLU()
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, pad_mode="same")

        self.layer1 = self._make_layer(block,
                                       layer_nums[0],
                                       in_channel=in_channels[0],
                                       out_channel=out_channels[0],
                                       stride=strides[0])
        self.layer2 = self._make_layer(block,
                                       layer_nums[1],
                                       in_channel=in_channels[1],
                                       out_channel=out_channels[1],
                                       stride=strides[1])
        self.layer3 = self._make_layer(block,
                                       layer_nums[2],
                                       in_channel=in_channels[2],
                                       out_channel=out_channels[2],
                                       stride=strides[2])
        self.layer4 = self._make_layer(block,
                                       layer_nums[3],
                                       in_channel=in_channels[3],
                                       out_channel=out_channels[3],
                                       stride=strides[3])

        self.mean = ops.ReduceMean(keep_dims=True)
        self.flatten = nn.Flatten()
        self.end_point = _fc(out_channels[3], num_classes)

    def _make_layer(self, block, layer_num, in_channel, out_channel, stride):
        """
        Make stage network of ResNet.

        Args:
            block (Cell): Resnet block.
            layer_num (int): Layer number.
            in_channel (int): Input channel.
            out_channel (int): Output channel.
            stride (int): Stride size for the first convolutional layer.

        Returns:
            SequentialCell, the output layer.

        Examples:
            >>> _make_layer(ResidualBlock, 3, 128, 256, 2)
        """
        layers = []

        resnet_block = block(in_channel, out_channel, stride=stride)
        layers.append(resnet_block)

        for _ in range(1, layer_num):
            resnet_block = block(out_channel, out_channel, stride=1)
            layers.append(resnet_block)

        return nn.SequentialCell(layers)

    def construct(self, x): # pylint: disable=missing-docstring
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        c1 = self.maxpool(x)

        c2 = self.layer1(c1)
        c3 = self.layer2(c2)
        c4 = self.layer3(c3)
        c5 = self.layer4(c4)

        out = self.mean(c5, (2, 3))
        out = self.flatten(out)
        out = self.end_point(out)

        return out


def resnet50(class_num=10):
    """
    Get ResNet50 neural network.

    Args:
        class_num (int): Class number.

    Returns:
        Cell, cell instance of ResNet50 neural network.

    Examples:
        >>> net = resnet50(10)
    """
    return ResNet(ResidualBlock,
                  [3, 4, 6, 3],
                  [64, 256, 512, 1024],
                  [256, 512, 1024, 2048],
                  [1, 2, 2, 2],
                  class_num)


def resnet101(class_num=1001):
    """
    Get ResNet101 neural network.

    Args:
        class_num (int): Class number.

    Returns:
        Cell, cell instance of ResNet101 neural network.

    Examples:
        >>> net = resnet101(1001)
    """
    return ResNet(ResidualBlock,
                  [3, 4, 23, 3],
                  [64, 256, 512, 1024],
                  [256, 512, 1024, 2048],
                  [1, 2, 2, 2],
                  class_num)

# %% [markdown]
# ### 步骤 2	自定义动态学习率

# %%
def get_lr(global_step,
           total_epochs,
           steps_per_epoch,
           lr_init=0.01,
           lr_max=0.1,
           warmup_epochs=5):
    """
    Generate learning rate array.

    Args:
        global_step (int): Initial step of training.
        total_epochs (int): Total epoch of training.
        steps_per_epoch (float): Steps of one epoch.
        lr_init (float): Initial learning rate. Default: 0.01.
        lr_max (float): Maximum learning rate. Default: 0.1.
        warmup_epochs (int): The number of warming up epochs. Default: 5.

    Returns:
        np.array, learning rate array.
    """
    lr_each_step = []
    total_steps = steps_per_epoch * total_epochs
    warmup_steps = steps_per_epoch * warmup_epochs
    if warmup_steps != 0:
        inc_each_step = (float(lr_max) - float(lr_init)) / float(warmup_steps)
    else:
        inc_each_step = 0
    for i in range(int(total_steps)):
        if i < warmup_steps:
            lr = float(lr_init) + inc_each_step * float(i)
        else:
            base = ( 1.0 - (float(i) - float(warmup_steps)) / (float(total_steps) - float(warmup_steps)) )
            lr = float(lr_max) * base * base
            if lr < 0.0:
                lr = 0.0
        lr_each_step.append(lr)

    current_step = global_step
    lr_each_step = np.array(lr_each_step).astype(np.float32)
    learning_rate = lr_each_step[current_step:]

    return learning_rate

# %% [markdown]
# ### 步骤 3	开始训练
# 完成数据预处理、网络定义、损失函数和优化器定义之后，开始模型训练。模型训练包含2层迭代，数据集的多伦迭代epoch和一轮数据集内按分组从数据集中抽取数据，输入网络计算得到损失函数，然后通过优化器计算和更新训练参数的梯度。

# %%
net=resnet50(class_num=cfg.num_class)
#计算softmax交叉熵。
loss = nn.SoftmaxCrossEntropyWithLogits(sparse=True, reduction="mean")
#设置Adam优化器
train_step_size = de_train.get_dataset_size()
lr = Tensor(get_lr(global_step=0, total_epochs=cfg.epoch_size, steps_per_epoch=train_step_size))
opt = Momentum(net.trainable_params(), lr, momentum=0.9, weight_decay=1e-4, loss_scale=cfg.loss_scale_num)
#opt = Momentum(filter(lambda x: x.requires_grad, net.get_parameters()), 0.002,
#                       0.9, 0.00004, loss_scale=1024.0)
loss_scale = FixedLossScaleManager(cfg.loss_scale_num, False)

model = Model(net, loss_fn=loss, optimizer=opt, loss_scale_manager=loss_scale, metrics={'acc'})
loss_cb = LossMonitor(per_print_times=train_step_size)
ckpt_config = CheckpointConfig(save_checkpoint_steps=cfg.save_checkpoint_steps, keep_checkpoint_max=1)
ckpoint_cb = ModelCheckpoint(prefix=cfg.prefix, directory=cfg.directory, config=ckpt_config)

print("============== Starting Training ==============")
model.train(cfg.epoch_size, de_train, callbacks=[loss_cb,ckpoint_cb], dataset_sink_mode=True)
# Out:
# ============== Starting Training ==============
# epoch: 1 step: 113, loss is 1.9270519
# epoch: 2 step: 113, loss is 1.7955425
# epoch: 3 step: 113, loss is 1.1291339
# epoch: 4 step: 113, loss is 1.1662602
# epoch: 5 step: 113, loss is 1.1014339
# epoch: 6 step: 113, loss is 0.8327851
# epoch: 7 step: 113, loss is 1.2901149
# epoch: 8 step: 113, loss is 0.8362386
# epoch: 9 step: 113, loss is 0.8682136
# epoch: 10 step: 113, loss is 0.8019649
# epoch: 11 step: 113, loss is 0.7219362
# epoch: 12 step: 113, loss is 0.6372356
# epoch: 13 step: 113, loss is 0.7447707
# epoch: 14 step: 113, loss is 0.62624425
# epoch: 15 step: 113, loss is 0.74613285
# epoch: 16 step: 113, loss is 0.5700913
# epoch: 17 step: 113, loss is 0.686046
# epoch: 18 step: 113, loss is 0.7409093
# epoch: 19 step: 113, loss is 0.53892285
# epoch: 20 step: 113, loss is 1.1531843
# epoch: 21 step: 113, loss is 0.60538155
# epoch: 22 step: 113, loss is 0.539676
# epoch: 23 step: 113, loss is 0.55641115
# epoch: 24 step: 113, loss is 0.61907774
# epoch: 25 step: 113, loss is 0.75669193
# epoch: 26 step: 113, loss is 0.7242313
# epoch: 27 step: 113, loss is 0.64928174
# epoch: 28 step: 113, loss is 0.83280426
# epoch: 29 step: 113, loss is 0.55104065
# epoch: 30 step: 113, loss is 0.2941845
# epoch: 31 step: 113, loss is 0.6989861
# epoch: 32 step: 113, loss is 0.3757348
# epoch: 33 step: 113, loss is 0.39002863
# epoch: 34 step: 113, loss is 0.34113938
# epoch: 35 step: 113, loss is 0.44110996
# epoch: 36 step: 113, loss is 0.1396396
# epoch: 37 step: 113, loss is 0.7617351
# epoch: 38 step: 113, loss is 0.5161283
# epoch: 39 step: 113, loss is 0.5926818
# epoch: 40 step: 113, loss is 0.4017155
# epoch: 41 step: 113, loss is 0.3818254
# epoch: 42 step: 113, loss is 0.45049948
# epoch: 43 step: 113, loss is 0.4253324
# epoch: 44 step: 113, loss is 0.31573653
# epoch: 45 step: 113, loss is 0.66128343
# epoch: 46 step: 113, loss is 0.34287626
# epoch: 47 step: 113, loss is 0.17206997
# epoch: 48 step: 113, loss is 0.25867447
# epoch: 49 step: 113, loss is 0.23470849
# epoch: 50 step: 113, loss is 0.21268785
# epoch: 51 step: 113, loss is 0.44248956
# epoch: 52 step: 113, loss is 0.34129775
# epoch: 53 step: 113, loss is 0.27381232
# epoch: 54 step: 113, loss is 0.5938961
# epoch: 55 step: 113, loss is 0.13838421
# epoch: 56 step: 113, loss is 0.3107253
# epoch: 57 step: 113, loss is 0.16056092
# epoch: 58 step: 113, loss is 0.20594114
# epoch: 59 step: 113, loss is 0.25710803
# epoch: 60 step: 113, loss is 0.38660687
# epoch: 61 step: 113, loss is 0.5795077
# epoch: 62 step: 113, loss is 0.4287935
# epoch: 63 step: 113, loss is 0.34537187
# epoch: 64 step: 113, loss is 0.25425524
# epoch: 65 step: 113, loss is 0.22755353
# epoch: 66 step: 113, loss is 0.16518639
# epoch: 67 step: 113, loss is 0.34346813
# epoch: 68 step: 113, loss is 0.21094084
# epoch: 69 step: 113, loss is 0.54997337
# epoch: 70 step: 113, loss is 0.09108496
# epoch: 71 step: 113, loss is 0.093743466
# epoch: 72 step: 113, loss is 0.3607247
# epoch: 73 step: 113, loss is 0.32223234
# epoch: 74 step: 113, loss is 0.18824151
# epoch: 75 step: 113, loss is 0.107468426
# epoch: 76 step: 113, loss is 0.29466745
# epoch: 77 step: 113, loss is 0.13246039
# epoch: 78 step: 113, loss is 0.016830318
# epoch: 79 step: 113, loss is 0.19054645
# epoch: 80 step: 113, loss is 0.14081183
# epoch: 81 step: 113, loss is 0.18264699
# epoch: 82 step: 113, loss is 0.097142756
# epoch: 83 step: 113, loss is 0.056197897
# epoch: 84 step: 113, loss is 0.10076671
# epoch: 85 step: 113, loss is 0.13258171
# epoch: 86 step: 113, loss is 0.12236001
# epoch: 87 step: 113, loss is 0.4038318
# epoch: 88 step: 113, loss is 0.09996331
# epoch: 89 step: 113, loss is 0.061688107
# epoch: 90 step: 113, loss is 0.078792095
# epoch: 91 step: 113, loss is 0.086184934
# epoch: 92 step: 113, loss is 0.06866664
# epoch: 93 step: 113, loss is 0.062159713
# epoch: 94 step: 113, loss is 0.052069634
# epoch: 95 step: 113, loss is 0.015427231
# epoch: 96 step: 113, loss is 0.17740181
# epoch: 97 step: 113, loss is 0.07108358
# epoch: 98 step: 113, loss is 0.0493325
# epoch: 99 step: 113, loss is 0.14752251
# epoch: 100 step: 113, loss is 0.050951827
# epoch: 101 step: 113, loss is 0.050827917
# epoch: 102 step: 113, loss is 0.026907938
# epoch: 103 step: 113, loss is 0.015353847
# epoch: 104 step: 113, loss is 0.110087186
# epoch: 105 step: 113, loss is 0.16931054
# epoch: 106 step: 113, loss is 0.04101579
# epoch: 107 step: 113, loss is 0.21638902
# epoch: 108 step: 113, loss is 0.058505967
# epoch: 109 step: 113, loss is 0.14731729
# epoch: 110 step: 113, loss is 0.029460847
# epoch: 111 step: 113, loss is 0.06029352
# epoch: 112 step: 113, loss is 0.067777485
# epoch: 113 step: 113, loss is 0.017216407
# epoch: 114 step: 113, loss is 0.03294672
# epoch: 115 step: 113, loss is 0.031648915
# epoch: 116 step: 113, loss is 0.13122845
# epoch: 117 step: 113, loss is 0.06937743
# epoch: 118 step: 113, loss is 0.002616854
# epoch: 119 step: 113, loss is 0.014625333
# epoch: 120 step: 113, loss is 0.0880657
# epoch: 121 step: 113, loss is 0.05371454
# epoch: 122 step: 113, loss is 0.0069508674
# epoch: 123 step: 113, loss is 0.009605912
# epoch: 124 step: 113, loss is 0.005929521
# epoch: 125 step: 113, loss is 0.0033228938
# epoch: 126 step: 113, loss is 0.09088826
# epoch: 127 step: 113, loss is 0.03507758
# epoch: 128 step: 113, loss is 0.006489232
# epoch: 129 step: 113, loss is 0.031840608
# epoch: 130 step: 113, loss is 0.020163354
# epoch: 131 step: 113, loss is 0.006948172
# epoch: 132 step: 113, loss is 0.0053776344
# epoch: 133 step: 113, loss is 0.0030451778
# epoch: 134 step: 113, loss is 0.005588494
# epoch: 135 step: 113, loss is 0.117134914
# epoch: 136 step: 113, loss is 0.0090172645
# epoch: 137 step: 113, loss is 0.009671001
# epoch: 138 step: 113, loss is 0.005881223
# epoch: 139 step: 113, loss is 0.036642272
# epoch: 140 step: 113, loss is 0.001078861
# epoch: 141 step: 113, loss is 0.012993587
# epoch: 142 step: 113, loss is 0.039893724
# epoch: 143 step: 113, loss is 0.060796585
# epoch: 144 step: 113, loss is 0.018644156
# epoch: 145 step: 113, loss is 0.0056231213
# epoch: 146 step: 113, loss is 0.01518851
# epoch: 147 step: 113, loss is 0.007869417
# epoch: 148 step: 113, loss is 0.012708086
# epoch: 149 step: 113, loss is 0.007246256
# epoch: 150 step: 113, loss is 0.020237034

# %% [markdown]
# ### 步骤 4	模型评估

# %%
# 使用测试集评估模型，打印总体准确率
metric = model.eval(de_test)
print(metric)
# Out:
# {'acc': 0.8846153846153846}

# %% [markdown]
# ## 5. 模型预测

# %%
# 预测
class_names = {0:'daisy',1:'dandelion',2:'roses',3:'sunflowers',4:'tulips'}
for i in range(10):
    test_ = de_test.create_dict_iterator().__next__()
    test = Tensor(test_['image'], mindspore.float32)
    predictions = model.predict(test)
    predictions = predictions.asnumpy()
    true_label = test_['label'].asnumpy()
    #显示预测结果
    p_np = predictions[0, :]
    pre_label = np.argmax(p_np)
    print('第' + str(i) + '个sample预测结果：', class_names[pre_label], '   真实结果：', class_names[true_label[0]])
# Out:
# 第0个sample预测结果： tulips    真实结果： tulips
# 第1个sample预测结果： sunflowers    真实结果： sunflowers
# 第2个sample预测结果： sunflowers    真实结果： sunflowers
# 第3个sample预测结果： sunflowers    真实结果： tulips
# 第4个sample预测结果： roses    真实结果： roses
# 第5个sample预测结果： dandelion    真实结果： dandelion
# 第6个sample预测结果： roses    真实结果： roses
# 第7个sample预测结果： tulips    真实结果： tulips
# 第8个sample预测结果： sunflowers    真实结果： sunflowers
# 第9个sample预测结果： dandelion    真实结果： dandelion

# %% [markdown]
# ## 6. 模型保存和转换
#
# ### 步骤 1	 保存模型为onnx格式

# %%
#创建文件夹
if not os.path.exists('./flowers/'):
    os.mkdir('./flowers/')
param_dict = load_checkpoint(os.path.join(cfg.directory,cfg.prefix+'-'+str(cfg.epoch_size)+'_'+str(train_step_size)+'.ckpt'))

# load the parameter into net
resnet=resnet50(class_num=cfg.num_class)
load_param_into_net(resnet, param_dict)
x = np.random.uniform(-1.0, 1.0, size = [1, 3, cfg.HEIGHT, cfg.WIDTH]).astype(np.float32)   
export(resnet, Tensor(x), file_name = './flowers/best_model.onnx', file_format = 'ONNX')

# %% [markdown]
# ### 步骤 2	 将模型保存到obs桶里面

# %%
#创建桶，根据自己情况修改路径
import moxing
moxing.file.copy_parallel(src_url='./flowers/best_model.onnx', dst_url='s3://ascblk/flower/onnx/best_model.onnx')
# Out:
# INFO:root:Using MoXing-v1.17.3-d858ff4a
# INFO:root:Using OBS-Python-SDK-3.20.9.1
